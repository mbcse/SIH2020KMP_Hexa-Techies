# %%
import csv

# %%
import os
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  'brute force.ipynb',
#  'final_script.ipynb',
#  'playing_with_csv.ipynb']

# %%
file_name='../checklist.csv'
rows=[]
with open(file_name, 'r',encoding="utf8") as csvfile:
    csvreader = csv.reader(csvfile) 
      
    # extracting field names through first row 
    fields = next(csvreader) 
  
    # extracting each data row one by one 
    for row in csvreader: 
        rows.append(row)

# %%
print(rows)
# Out:
# [[], ['', 'ITEMS ', 'STANDARDS ', 'REF ANN. 14 ', 'C ', 'N C ', 'N/A ', 'COMMENTS ', ''], ['', '3.1 Runways ', 'RWY surfaces WIO irregularities ', '3.1.22 ', '', '', '', '', ''], ['', '', 'RWY', ' friction characteristics on wet ', '3.1.23 ', '', '', '', '', ''], ['', '', 'pavement ', '', '', '', '', '', ''], ['', '3.2 Runway ', 'No standard ', '', '', '', '', '', ''], ['', 'Shoulders ', '', '', '', '', '', '', ''], ['', '3.3 Runway Turn ', 'Application for code D', ' E or F ', '3.3.1 ', '', '', '', '', ''], ['', 'Pads ', 'Runway turn pad - design ', '3.3.6 ', '', '', '', '', ''], ['', '', 'Surface of RWY turn pads ', '3.3.10 ', '', '', '', '', ''], ['', '3.4 Runway Strips ', 'General - RWY and stop way included in ', '3.4.1 ', '', '', '', '', ''], ['', '', 'runway strip ', '', '', '', '', '', ''], ['', '', 'Length of rwy strip ', '3.4.2 ', '', '', '', '', ''], ['', '', 'Width of rwy strip ', '3.4.3 ', '', '', '', '', ''], ['', '', 'Objects on rwy strip ', '3.4.7 ', '', '', '', '', ''], ['', '', 'Junction rwy and other surfaces ', '3.4.10 ', '', '', '', '', ''], ['', '3.5 Runway End ', 'General - mandatory depending on runway ', '3.5.1 ', '', '', '', '', ''], ['', 'Safety Area (RESA) ', 'code ', '', '', '', '', '', ''], ['', '', 'Dimensions', ' length ', '3.5.2 ', '', '', '', '', ''], ['', '', 'Dimensions width ', '3.5.4 ', '', '', '', '', ''], ['', '3.6 Clearways ', 'No standard ', '', '', '', '', '', ''], ['', '3.7 Stop ways ', 'Width ', '3.7.1 ', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '3.8 Radio Altimeter ', 'No standard ', '', '', '', '', '', ''], ['', 'Operating Area ', '', '', '', '', '', '', ''], [], [], [], [], [], ['Table: Table_1'], [], ['20. ', '3.9 Taxiways ', 'Clearances', ' design ', '3.9.4 ', '', '', '', '', ''], ['21. ', '', 'Taxiways on bridge ', '3.9.20 ', '', '', '', '', ''], ['22. ', '3.10 Taxiway ', 'No standard ', '', '', '', '', '', ''], ['', 'shoulders ', '', '', '', '', '', '', ''], ['23. ', '3.11 TWY strips ', 'Twy included in a strip ', '3.11.1 ', '', '', '', '', ''], ['24. ', '3.12 Holding bays', ' ', 'Establishment criteria rwy-holding position ', '3.12.2 ', '', '', '', '', ''], ['', 'rwy-holding ', 'Establishment criteria rwy-holding position ', '3.12.3 ', '', '', '', '', ''], ['25. ', 'positions', ' ', 'to protect navaids ', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['26. ', 'intermediate holding ', 'Road-holding position - rwy ', '3.12.5 ', '', '', '', '', ''], ['27. ', 'positions', ' road- ', 'Location of above signs ', '3.12.6 ', '', '', '', '', ''], ['28. ', 'holding positions ', 'RWY holding position & ILS protection ', '3.12.9 ', '', '', '', '', ''], ['29. ', '3.13 Apron ', 'No standard ', '', '', '', '', '', ''], ['30. ', '3.14 Isolated aircraft ', 'Identification of an isolated aircraft parking ', '3.14.1 ', '', '', '', '', ''], ['', 'parking position ', 'position ', '', '', '', '', '', ''], ['31. ', '3.15 De-icing ', 'No standard ', '', '', '', '', '', ''], ['', 'facilities ', '', '', '', '', '', '', ''], ['32 ', '4.1 Obstacle ', 'Conical surface', ' description ', 'GSR 751 ', '', '', '', '', ''], ['33. ', 'Limitation Surfaces ', 'Conical surface', ' characteristics ', 'GSR 751 ', '', '', '', '', ''], ['34. ', '', 'Conical surface', ' slopes ', 'GSR 751 ', '', '', '', '', ''], ['35. ', 'Inner horizonta ', 'Description ', 'GSR 751 ', '', '', '', '', ''], ['36. ', 'surface ', 'Characteristics ', 'GSR 751 ', '', '', '', '', ''], ['37. ', '', 'Height', ' method of measurement ', 'GSR 751 ', '', '', '', '', ''], ['38. ', 'Approach surface ', 'Description ', 'GSR 751 ', '', '', '', '', ''], ['39. ', '', 'Characteristics ', 'GSR 751 ', '', '', '', '', ''], ['40. ', '', 'Elevation of inner edge ', 'GSR 751 ', '', '', '', '', ''], ['41. ', '', 'Slope of approach surface ', 'GSR 751 ', '', '', '', '', ''], ['42. ', 'Inner approach ', 'Description ', 'GSR 751 ', '', '', '', '', ''], ['43. ', '', '', '', '', '', '', '', ''], [], [], [], [], [], ['Table:  ...

# %%
#removing empty lines
master_list = []
for i in range(len(rows)):  
    #print("rows:",rows[i])
    if(len(rows[i])>=2):
        temp = []
        for j in range(len(rows[i])):
            if(len(rows[i][j])>1):
                temp.append(rows[i][j].strip())
        #print("temp:",temp)
        master_list.append(temp)
    
print(master_list)
# Out:
# [['ITEMS', 'STANDARDS', 'REF ANN. 14', 'C', 'N C', 'N/A', 'COMMENTS'], ['3.1 Runways', 'RWY surfaces WIO irregularities', '3.1.22'], ['RWY', 'friction characteristics on wet', '3.1.23'], ['pavement'], ['3.2 Runway', 'No standard'], ['Shoulders'], ['3.3 Runway Turn', 'Application for code D', 'E or F', '3.3.1'], ['Pads', 'Runway turn pad - design', '3.3.6'], ['Surface of RWY turn pads', '3.3.10'], ['3.4 Runway Strips', 'General - RWY and stop way included in', '3.4.1'], ['runway strip'], ['Length of rwy strip', '3.4.2'], ['Width of rwy strip', '3.4.3'], ['Objects on rwy strip', '3.4.7'], ['Junction rwy and other surfaces', '3.4.10'], ['3.5 Runway End', 'General - mandatory depending on runway', '3.5.1'], ['Safety Area (RESA)', 'code'], ['Dimensions', 'length', '3.5.2'], ['Dimensions width', '3.5.4'], ['3.6 Clearways', 'No standard'], ['3.7 Stop ways', 'Width', '3.7.1'], [], ['3.8 Radio Altimeter', 'No standard'], ['Operating Area'], ['20.', '3.9 Taxiways', 'Clearances', 'design', '3.9.4'], ['21.', 'Taxiways on bridge', '3.9.20'], ['22.', '3.10 Taxiway', 'No standard'], ['shoulders'], ['23.', '3.11 TWY strips', 'Twy included in a strip', '3.11.1'], ['24.', '3.12 Holding bays', 'Establishment criteria rwy-holding position', '3.12.2'], ['rwy-holding', 'Establishment criteria rwy-holding position', '3.12.3'], ['25.', 'positions', 'to protect navaids'], [], ['26.', 'intermediate holding', 'Road-holding position - rwy', '3.12.5'], ['27.', 'positions', 'road-', 'Location of above signs', '3.12.6'], ['28.', 'holding positions', 'RWY holding position & ILS protection', '3.12.9'], ['29.', '3.13 Apron', 'No standard'], ['30.', '3.14 Isolated aircraft', 'Identification of an isolated aircraft parking', '3.14.1'], ['parking position', 'position'], ['31.', '3.15 De-icing', 'No standard'], ['facilities'], ['32', '4.1 Obstacle', 'Conical surface', 'description', 'GSR 751'], ['33.', 'Limitation Surfaces', 'Conical surface', 'characteristics', 'GSR 751'], ['34.', 'Conical surface', 'slopes', 'GSR 751'], ['35.', 'Inner horizonta', 'Description', 'GSR 751'], ['36.', 'surface', 'Characteristics', 'GSR 751'], ['37.', 'Height', 'method of measurement', 'GSR 751'], ['38.', 'Approach surface', 'Description', 'GSR 751'], ['39.', 'Characteristics', 'GSR 751'], ['40.', 'Elevation of inner edge', 'GSR 751'], ['41.', 'Slope of approach surface', 'GSR 751'], ['42.', 'Inner approach', 'Description', 'GSR 751'], ['43.'], ['44.', 'Transitional surface', 'Description', 'GSR 751'], ['45.', 'Characteristics', 'GSR 751'], ['46.', 'Elevation', 'GSR 751'], ['47.', 'Slopes', 'GSR 751'], ['48.', 'Inner transitional', 'Description', 'GSR 751'], ['49.', 'surface', 'Characteristics', 'GSR 751'], ['50.', 'Elevation', 'GSR 751'], ['51.', 'Slopes', 'GSR 751'], ['52.', 'Balked landing', 'Description', 'GSR 751'], ['53.', 'surface', 'Characteristics', 'GSR 751'], ['54.', 'Elevation', 'GSR 751'], ['55.', 'Slopes', 'GSR 751'], ['56.', 'Take-off climb', 'Description', 'GSR 751'], ['57.', 'surface', 'Characteristics', 'GSR 751'], ['58.', 'Elevationof inner edge', 'GSR 751'], ['59.', 'Take-off flight path', 'Measurement -A', 'GSR 751'], ['60.', 'Measurement - - B', 'GSR 751'], ['61.', '4.2 Obstacle', 'Obstacle limitations depending on the', 'GSR 751'], ['limitation', 'type of surface', 'GSR 751'], ['requirements - No-', 'Height and slope of various types of', 'GSR 751'], ['62.', 'instrument runways', 'surface', 'GSR 751'], ['63', 'New objects or extension of existing', 'GSR 751'], ['objects', 'GSR 751'], ['Obstacle limitation', 'Obstacle limitations depending on the', 'GSR 751'], ['64.', 'requirements-no', 'type of surface', 'GSR 751'], ['65', 'precision approach', 'Height and slope of surfaces - A', 'GSR 751'], ['66.', 'runway', 'Height and slope of surfaces - B', 'GSR 751'], ['67.', 'New objects or extension of existing', 'GSR 751'], ['68.', 'Obstacle limitation', 'Types of surfaces. CAT I', 'GSR 751'], ['69.', 'requirements', 'Types of surfaces. CAT II and III', 'GSR 751'], ['70 ...

# %%
for i in range(len(master_list)):
    print(master_list[i])
# Out:
# ['ITEMS', 'STANDARDS', 'REF ANN. 14', 'C', 'N C', 'N/A', 'COMMENTS']
# ['3.1 Runways', 'RWY surfaces WIO irregularities', '3.1.22']
# ['RWY', 'friction characteristics on wet', '3.1.23']
# ['pavement']
# ['3.2 Runway', 'No standard']
# ['Shoulders']
# ['3.3 Runway Turn', 'Application for code D', 'E or F', '3.3.1']
# ['Pads', 'Runway turn pad - design', '3.3.6']
# ['Surface of RWY turn pads', '3.3.10']
# ['3.4 Runway Strips', 'General - RWY and stop way included in', '3.4.1']
# ['runway strip']
# ['Length of rwy strip', '3.4.2']
# ['Width of rwy strip', '3.4.3']
# ['Objects on rwy strip', '3.4.7']
# ['Junction rwy and other surfaces', '3.4.10']
# ['3.5 Runway End', 'General - mandatory depending on runway', '3.5.1']
# ['Safety Area (RESA)', 'code']
# ['Dimensions', 'length', '3.5.2']
# ['Dimensions width', '3.5.4']
# ['3.6 Clearways', 'No standard']
# ['3.7 Stop ways', 'Width', '3.7.1']
# []
# ['3.8 Radio Altimeter', 'No standard']
# ['Operating Area']
# ['20.', '3.9 Taxiways', 'Clearances', 'design', '3.9.4']
# ['21.', 'Taxiways on bridge', '3.9.20']
# ['22.', '3.10 Taxiway', 'No standard']
# ['shoulders']
# ['23.', '3.11 TWY strips', 'Twy included in a strip', '3.11.1']
# ['24.', '3.12 Holding bays', 'Establishment criteria rwy-holding position', '3.12.2']
# ['rwy-holding', 'Establishment criteria rwy-holding position', '3.12.3']
# ['25.', 'positions', 'to protect navaids']
# []
# ['26.', 'intermediate holding', 'Road-holding position - rwy', '3.12.5']
# ['27.', 'positions', 'road-', 'Location of above signs', '3.12.6']
# ['28.', 'holding positions', 'RWY holding position & ILS protection', '3.12.9']
# ['29.', '3.13 Apron', 'No standard']
# ['30.', '3.14 Isolated aircraft', 'Identification of an isolated aircraft parking', '3.14.1']
# ['parking position', 'position']
# ['31.', '3.15 De-icing', 'No standard']
# ['facilities']
# ['32', '4.1 Obstacle', 'Conical surface', 'description', 'GSR 751']
# ['33.', 'Limitation Surfaces', 'Conical surface', 'characteristics', 'GSR 751']
# ['34.', 'Conical surface', 'slopes', 'GSR 751']
# ['35.', 'Inner horizonta', 'Description', 'GSR 751']
# ['36.', 'surface', 'Characteristics', 'GSR 751']
# ['37.', 'Height', 'method of measurement', 'GSR 751']
# ['38.', 'Approach surface', 'Description', 'GSR 751']
# ['39.', 'Characteristics', 'GSR 751']
# ['40.', 'Elevation of inner edge', 'GSR 751']
# ['41.', 'Slope of approach surface', 'GSR 751']
# ['42.', 'Inner approach', 'Description', 'GSR 751']
# ['43.']
# ['44.', 'Transitional surface', 'Description', 'GSR 751']
# ['45.', 'Characteristics', 'GSR 751']
# ['46.', 'Elevation', 'GSR 751']
# ['47.', 'Slopes', 'GSR 751']
# ['48.', 'Inner transitional', 'Description', 'GSR 751']
# ['49.', 'surface', 'Characteristics', 'GSR 751']
# ['50.', 'Elevation', 'GSR 751']
# ['51.', 'Slopes', 'GSR 751']
# ['52.', 'Balked landing', 'Description', 'GSR 751']
# ['53.', 'surface', 'Characteristics', 'GSR 751']
# ['54.', 'Elevation', 'GSR 751']
# ['55.', 'Slopes', 'GSR 751']
# ['56.', 'Take-off climb', 'Description', 'GSR 751']
# ['57.', 'surface', 'Characteristics', 'GSR 751']
# ['58.', 'Elevationof inner edge', 'GSR 751']
# ['59.', 'Take-off flight path', 'Measurement -A', 'GSR 751']
# ['60.', 'Measurement - - B', 'GSR 751']
# ['61.', '4.2 Obstacle', 'Obstacle limitations depending on the', 'GSR 751']
# ['limitation', 'type of surface', 'GSR 751']
# ['requirements - No-', 'Height and slope of various types of', 'GSR 751']
# ['62.', 'instrument runways', 'surface', 'GSR 751']
# ['63', 'New objects or extension of existing', 'GSR 751']
# ['objects', 'GSR 751']
# ['Obstacle limitation', 'Obstacle limitations depending on the', 'GSR 751']
# ['64.', 'requirements-no', 'type of surface', 'GSR 751']
# ['65', 'precision approach', 'Height and slope of surfaces - A', 'GSR 751']
# ['66.', 'runway', 'Height and slope of surfaces - B', 'GSR 751']
# ['67.', 'New objects or extension of existing', 'GSR 751']
# ['68.', 'Obstacle limitation', 'Types of surfaces. CAT I', 'GSR 751']
# ['69.', 'requirements', 'Types of surfaces. CAT II and III', 'GSR 751']
# ['70.', 'precision approach', 'Height & slope of surfaces - A', 'GSR 751']
# ['71.', 'runway', 'Height & slopes of surfaces - B', 'GSR 751']
# ['72.', 'Fixed objects above surfaces', 'GSR 751']
# ['New objects or extension of existing', 'GSR 751']
# ['73.', 'objects', 'GSR 751']
# ['74.', 'Runways meant for', 'Type of obstacle limitation surface', 'GSR 751']
# ['75.', 'take-off', 'Dimensions of surfaces', 'GSR 751']
# ['New objects or extension of existing', 'GSR 751']
# ['76.', 'objects']
# ['77.', '5.1 -Indicators and']
# ['signalling devices']
# ['78.', 'Wind direction', 'Availability', '5.1.1.1']
# ['79.', 'indicator', 'Location', '5.1.1.2']
# ['80.', 'Landing direction', 'Availability', '5.1.2.1']
# ['81.', 'indicator', 'Location', '5.1.2.3']
# ['82.', 'Signalling lamp', 'Application', '5.1.3.1']
# ['Signal panels &', 'Characteristics of signal area', '5.1.4.2']
# ['83.', 'signal area']
# ['84.', '5.2 Markings']
# ['85.', 'Generals', 'General', 'interruption of runway', '5.2.1.1']
# ['marking']
# ['86.', 'Interruption intersection rwy and twy', '5.2.1.3']
# ['87.', 'Color and conspicuity', 'RWY marking - White', '5.2.1.4']
# ['88.', 'TWY and other marking Yellow', '5.2.1.5']
# ['89.', 'Apron safety lines conspicuous', '5.2.1.6']
# ['90.', 'Runway designation', 'Marking at threshold', '5.2.2.1']
# ['91.', 'marking', 'Location of marking', '5.2.2.3']
# ['92.', 'Characteristics', '5.2.2.4']
# ['93.', 'Marking parallel runways', '5.2.2.5']
# ['94.', 'Proportions numbers and letters', '5.2.2.6']
# ['95.', 'Runway center line', 'Application', '5.2.3.1']
# ['96.', 'marking', 'Location', '5.2.3.2']
# ['97.', 'Characteristics', '5.2.3.3']
# ['98', 'Width of stripes', '5.2.3.4']
# ['100.', 'Location', '5.2.4.4']
# ['101.', 'Characteristics', '5.2.4.5']
# ['102.', 'Surface to be covered', '5.2.4.6']
# ['103.', 'Transverse stripe', 'Stripe width', '5.2.4.8']
# ['104.', 'Arrows', 'Permanently displaced threshold', '5.2.4.9']
# ['105.', 'Temporarily displaced threshold', '5.2.4.10']
# ['106.', 'Aiming point marking', 'Application', '5.2.5.1']
# ['107.', 'Use according with runway code', '5.2.5.2']
# ['108.', 'Location', '5.2.5.4']
# ['109.', 'Characteristics', '5.2.5.5']
# ['110.', 'Touchdown zone', 'Application', '5.2.6.1']
# ['111.', 'marking', 'Location and Characteristics', '5.2.6.3']
# ['112.', 'Configuration A et B', '5.2.6.4']
# ['113.', 'Runway side stripe', 'Application', '5.2.7.1']
# ['marking']
# ['114.', 'Taxiway centre line', 'Application', '5.2.8.1']
# ['115.', 'marking', 'Standard taxi-route marking', '5.2.8.3']
# ['116.', 'Enhanced taxiway centre line marking', '5.2.8.5']
# ['117.', 'Location', 'enhanced marking', '5.2.8.9']
# ['118.', 'Characteristics - enhanced marking', '5.2.8.10']
# ['119.', 'Characteristics - figure 5-7', '5.2.8.11']
# ['120.', 'Runway turn pad', 'Application', '5.2.9.1']
# ['121.', 'marking', 'Characteristics', '5.2.9.7']
# ['122.', 'Runway-holding', 'Application and Location', '5.2.10.1']
# ['123.', 'position marking', 'Characteristics', '5.2.10.2']
# ['124.', 'Holding point Cat I', 'II and III', '5.2.10.3']
# ['125.', 'Runway-holding position', 'pattern A', '5.2.10.4']
# ['126.', 'Runway-holding position', 'runway', '5.2.10.7']
# ['intersection', 'pattern A']
# ['127.', 'Intermediate holding', 'Intersection - 2 taxiways', '5.2.11.3']
# ['128.', 'position marking', 'Distance between holding position', '5.2.11.4']
# []
# ['129.', 'Characteristics', '5.2.11.5']
# ['130.', 'VOR Airport', 'Application', '5.2.12.1']
# ['131.', 'checkpoint marking', 'Site Selection', '5.2.12.2']
# ['132.', 'Location', '5.2.12.3']
# ['133.', 'Characteristics', '5.2.12.4']
# ['134.', 'Aircraft stand mark', 'No standard']
# ['135.', 'Apron safety line', 'Location', '5.2.14.2']
# ['136.', 'Road-holding position', 'Application', '5.2.15.1']
# ['137.', 'marking', 'Location', '5.2.15.2']
# ['138.', 'Characteristics local traffic regulation', '5.2.15.3']
# ['139.', 'Mandatory instruction', 'Application', '5.2.16.1']
# ['140.', 'marking', 'Location', 'code letter A', 'B', 'C and D', '5.2.16.3']
# ['141.', 'Location', 'code letter E and F', '5.2.16.4']
# ['142.', 'Characteristics - No entry.', '5.2.16.6']
# ['143.', 'Characteristics - No entry', 'colors', '5.2.16.7']
# ['144.', 'Characteristics - Conspicuity', '5.2.16.8']
# ['145.', 'Information marking', 'Application', '5.2.17.1']
# ['146.', 'Characteristics', '5.2.17.6']
# ['147.', 'Conspicuity', '5.2.17.7']
# ['148.', '5.3 Lights']
# ['General', 'Lights which may endanger safety of', '5.3.1.1']
# ['149.', 'aircraft']
# ['150.', 'Elevated approach', 'Frangibility', '5.3.1.4']
# ['151.', 'lights', '5.3.1.4 applicable after January 1', '5.3.1.5']
# ['2005']
# ['152.', 'Marking for conspicuity', '5.3.1.6']
# ['153.', 'Elevated lights', 'Frangibility and clearance for', '5.3.1.7']
# ['propellers']
# ['154.', 'Surface lights', 'Design', '5.3.1.8']
# ['155.', 'Light intensity and', 'Intensity for visibility', '5.3.1.10']
# ['156.', 'control', 'Intensity control', '5.3.1.11']
# ['157.', 'Intensity maximum A', '5.3.1.12']
# ['158.', 'Intensity maximum B', '5.3.1.13']
# []
# ['Aeronautical beacons', 'If operationally required', '5.3.3.1']
# ['Requirements for establishing', '5.3.3.2']
# ['necessity']
# ['Airport beacons', 'Conditions to have a beacon', '5.3.3.3']
# ['Location', '5.3.3.4']
# ['Characteristics', '5.3.3.6']
# ['Visibility angles', '5.3.3.7']
# ['dentification beacon', 'Application', '5.3.3.8']
# ['Location', '5.3.3.9']
# ['Characteristics', '5.3.3.11']
# ['Colour of flashing lights', '5.3.3.12']
# ['Identification', 'Morse code', '5.3.3.13']
# ['characters']
# ['Approach lighting', 'Application', 'non-instrument RWY', '5.3.4.1']
# ['system', 'Application non-precision approach', '5.3.4.1']
# ['runway']
# ['Application', 'Precision approach', '5.3.4.1']
# ['runway CAT I']
# ['Application', 'Precision approach', '5.3.4.1']
# ['runway CAT II and III']
# ['Simple approach', 'Location', '5.3.4.2']
# ['lighting system', 'Position of lights on crossbar', '5.3.4.3']
# ['Centre line lights', '5.3.4.4']
# ['Position of the system - plane to thld', '5.3.4.6']
# ['Characteristics', '5.3.4.7']
# ['Precision approach', 'Location', '5.3.4.10']
# ['CAT I lighting system', 'Position - runway centre line', '5.3.4.11']
# ['Centre line - space between lights', '5.3.4.12']
# ['Position of the system - horizontal', '5.3.4.13']
# ['plane through the threshold']
# ['Characteristics - fixed lights showing', '5.3.4.14']
# ['variable white']
# ['Serviceability level', '5.3.4.15']
# ['Barrettes - light spacing', '5.3.4.16']
# ['Number of flashes per second.', '5.3.4.18']
# ['Independent operation']
# ['Additional lights on crossbar.', '5.3.4.19']
# ['Position of additional lights', '5.3.4.20']
# ['Lights conform to Appendix 2', 'Figure', '5.3.4.21']
# ['A2-1']
# ['Precision approach', 'Location distance in the extended', '5.3.4.22']
# ['CAT II and III lighting', 'center line']
# ['system', 'Location longitudinal intervals', '5.3.4.23']
# ['Location - on barrettes', '5.3.4.24']
# ['Crossbar at 150 meters', '5.3.4.25']
# ['Crossbar at 300 meters', '5.3.4.26']
# ['Additional crossbars', '5.3.4.27']
# ['Position of lights on additional', '5.3.4.28']
# ['crossbars']
# ['Position horizontal plan', '5.3.4.29']
# ['Characteristics - for the first 300 m.', '5.3.4.30']
# ['Characteristics - over 300 meters', '5.3.4.31']
# ['Characteristics - Others', '5.3.4.32']
# ['Characteristics - Length of barrettes', '5.3.4.33']
# ['Characteristics - Flash per second', '5.3.4.35']
# ['and independent control']
# ['Characteristics - Side row', 'color red', '5.3.4.36']
# ['Characteristics - Fixed lights', 'variable', '5.3.4.37']
# ['white']
# ['Characteristics - Compatibility', '5.3.4.38']
# ['between red and white lights']
# ['Characteristics - Lights as per App 2', '5.3.4.39']
# ['fig A2-1 & A2-2']
# ['Visual Approach', 'Application - Conditions for', '5.3.5.1']
# ['Slope Indicator', 'establishment']
# ['System', 'Application -']
# ['Application - Criteria for installation', '5.3.5.3']
# ['Application - Criteria for installation', '5.3.5.4']
# ['T-VASIS & AT-VASIS', 'description', '5.3.5.6']
# ['T-VASIS & AT-VASIS', 'description', '5.3.5.7']
# ['T-VASIS & AT-VASIS', 'description', '5.3.5.8']
# ['T-VASIS & AT-VASIS - Location', '5.3.5.9']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.10']
# ['light units']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.11']
# ['light units']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.12']
# ['light units']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.13']
# ['light units']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.14']
# ['light units']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.15']
# ['light units']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.16']
# ['light units']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.17']
# ['light units']
# ['Approach slope and', 'Approach slope appropriate for', '5.3.5.18']
# ['elevation settings of', 'aircraft using the approach']
# ['light beams', 'Visual approach slope conform', '5.3.5.19']
# ['between ILS and visual aids']
# ['Same setting', 'both end of runway', '5.3.5.20']
# ['Slope to clear all objects', '5.3.5.21']
# ['Adjustment of azimuth', '5.3.5.22']
# ['PAPI et APAPI', 'Description: PAPI', '5.3.5.23']
# ['Description: APAPI', '5.3.5.24']
# ['Description: PAPI position of red and', '5.3.5.25']
# ['white lights']
# ['Description: APAPI position of red', '5.3.5.26']
# ['and white lights']
# ['Location: figure 5-18', '5.3.5.27']
# ['Characteristics: day and night', '5.3.5.28']
# ['operation']
# ['Characteristics: others', '5.3.5.29']
# []
# ['Characteristics: others', '5.3.5.30']
# ['Distribution light intensity', 'App. 2', '5.3.5.31']
# ['Figure A2-23']
# ['Intensity control', '5.3.5.32']
# ['Adjustment in elevation - limits', '5.3.5.33']
# ['Design to avoid accumulation of FOD', '5.3.5.34']
# ['Approach slope', 'figure 5-19', '5.3.5.35']
# ['Compatibility with ILS slope', '5.3.5.36']
# ['Slope angle to clear all objects.', '5.3.5.37']
# ['Same for APAP', '5.3.5.38']
# ['Azimuth spread of the light beam', '5.3.5.39']
# ['Same setting at both end of rwy', '5.3.5.40']
# ['Establishment of an obstacle', '5.3.5.41']
# ['protection surface']
# ['Characteristic of the protection', '5.3.5.42']
# ['surface', 'Tableau 5-3 et fig. 5-20']
# ['New objects or extension of existing', '5.3.5.43']
# ['objects']
# ['Removal of objects above obstacle', '5.3.5.44']
# ['protection surface']
# ['Mitigation measures', '5.3.5.45']
# ['RWY lead-in lighting', 'No standard']
# ['RWY threshold', 'Location', '5.3.8.2']
# ['identification lights', 'Visible in the approach direction', '5.3.8.4']
# ['Runway edge lights', 'Application criteria', 'night operation or', '5.3.9.1']
# ['day and night for precision approach']
# ['Location', '2 parallel row equidistant', '5.3.9.3']
# ['from the rwy centre line']
# ['Location less than 3 metres from the', '5.3.9.4']
# ['edge of the rwy']
# ['Distance between lights', '60 or 100', '5.3.9.6']
# ['meters']
# ['Characteristics: fix', 'white', 'variable', '5.3.9.7']
# ['intensity']
# ['Characteristics visible all angles', '5.3.9.8']
# ['Characteristics: 15 degrees above', '5.3.9.9']
# ['the horizon']
# ['Characteristics: precision approach', '5.3.9.10']
# ['App 2', 'fig A2-9 and A2-10']
# ['Runway threshold', 'Application - RWY THLD Lights', '5.3.10.1']
# ['and wing bar lights', 'Location of lights at rwy end', '5.3.10.2']
# ['Location THLD lights', 'displaced thld', '5.3.10.3']
# ['Threshold: number of lights', '5.3.10.4']
# ['Wing bar thld lights', 'displaced thld', '5.3.10.7']
# ['Location of wing bar lights', '5.3.10.8']
# ['Characteristics: green', '5.3.10.9']
# ['unidirectional and fix']
# ['Thld light', 'precision approach App. 2', '5.3.10.10']
# ['Fig. A2-3']
# ['Thld wing bar light with precision', '5.3.10.11']
# ['Approach App 2', 'Fig. A2-4']
# ['Runway end lights', 'Mandatory for rwy equipped with edge', '5.3.11.1']
# ['lights']
# ['Location', '5.3.11.2']
# ['275.', 'Characteristics: fix', 'unidirectional.', 'red', '5.3.11.4']
# ['direction rwy']
# ['Rwy end with precision approach', '5.3.11.5']
# ['276.', 'App 2', 'Fig A2-8']
# ['Runway Center Line', 'Mandatory for precision approach', '5.3.12.1']
# ['277.', 'Lights', 'CAT II and III']
# ['Mandatory for T/Off with RVR less', '5.3.12.3']
# ['278.', 'than 400 m.']
# ['279.', 'Location of lights', '5.3.12.5']
# ['Characteristics: fix', 'white', 'variable', '5.3.12.7']
# ['280.', 'intensity', 'etc.']
# ['Characteristics: accordance with', '5.3.12.8']
# ['281.', 'App. 2', 'Fig. A2-6 and A2-7']
# ['282.', 'Runway touchdown', 'Mandatory for precision approach Cat', '5.3.13.1']
# ['zone lights', 'II et III']
# ['283.', 'Location', '5.3.13.2']
# ['Characteristics: number of lights per', '5.3.13.3']
# ['284.', 'barrette and spacing']
# ['285.', 'Characteristics: fix', 'unidirectional', '5.3.13.5']
# ['white', 'variable']
# ['Accordance with spec. App 2', 'Fig. A2-', '5.3.13.6']
# ['286.', '5']
# ['287.', 'Rapid exit taxiway', 'Not to be on if pattern is not as fig 5-', '5.3.14.2']
# ['indicator lights', '24', 'in full.']
# ['288.', 'Located same side of the CL as the', '5.3.14.3']
# ['TWY', 'configur. Fig 5-23']
# ['289.', 'No overlapping when displayed', '5.3.14.4']
# ['Light yellow', 'unidirectional fix', '5.3.14.5']
# ['290.', 'visible direction approach.']
# ["Conform spec. 'App. 2", 'Fig. A2-6 or', '5.3.14.6']
# ['291.', 'A2-7']
# ['292.', 'if used at', '5.3.15.1']
# ['Location', '5.3.15.2']
# ['Characteristics', '5.3.15.3']
# ['Taxiway centre line', 'Mandatory is use with RVR less than', '5.3.16.1']
# ['lights', '350 m.']
# ['TWY lights on RWY if used as a', '5.3.16.4']
# ['standard taxi route']
# ['Characteristics: green with reduced', '5.3.16.6']
# ['beam dimensions']
# ['TWY lights on RWY exit shall be', '5.3.16.7']
# ['alternatively green & yellow', 'etc.']
# ['Conform Appendix 2', 'various figures', '5.3.16.8']
# ['Taxiway edge lights', 'Installed on rwy turn pas', 'holding bay', '5.3.17.1']
# ['and apron', 'etc. if used at night']
# ['Installed on rwy is part of taxi-route.', '5.3.17.2']
# ['Characteristics: blue', 'fix', 'visible 30', '5.3.17.7']
# ['degrees above the horizon']
# ['Runway turn pad', 'Application', '5.3.18.1']
# ['lights', 'Light fix', 'unidirectional', 'green', '5.3.18.6']
# ['Conform spec. Appendices 2', 'Fig. A2-', '5.3.18.7']
# ['13', '14 ou 15']
# ['Stop bars', 'Mandatory if rwy use RVR les than', '5.3.19.1']
# ['350 m', 'etc.']
# ['Mandatory if rwy use with RVR', '5.3.19.2']
# ['between 350 and 550 m.']
# ['Location', '5.3.19.5']
# ['Characteristics: Light red', 'spacing 3', '5.3.19.6']
# ['m. etc']
# ['Characteristics: Rwy-holding position', '5.3.19.7']
# ['unidirectional', 'red', 'visible when']
# ['approaching rwy']
# ['Additional lights as spec. 5.3.19.4', '5.3.19.8']
# ['switchable bars', '5.3.19.9']
# ['Intensity lights spread']
# ['313.', 'App. 2', 'Fig.: Q2-12 to to16']
# ['314.', 'Electrical circuit: design', '5.3.19.13']
# ['315.', 'Intermediate holding', 'Conditions for installation', '5.3.20.1']
# ['316.', 'position lights', 'Location', '5.3.20.3']
# ['317.', 'Characteristics', '5.3.20.4']
# ['318.', 'De-icing/anti-icing', 'Location', '5.3.21.2']
# ['319.', 'facility exit lights', 'Characteristics', '5.3.21.3']
# ['320.', 'Runway Guard Lights', 'Application', '5.3.22.1']
# ['321.', 'Location configuration A', '5.3.22.4']
# ['322.', 'Location configuration B', '5.3.22.5']
# ['323.', 'Characteristics configuration A', '5.3.22.6']
# ['324.', 'Characteristics configuration B', '5.3.22.8']
# ['325.', 'Light beam definition', '5.3.22.9']
# ['326.', 'Lighting sequence light', 'confi. A', '5.3.22.16']
# ['327.', 'Lighting sequence light Config. B', '5.3.22.17']
# ['328.', 'Cycle 30 a 60 cycles per minute', '5.3.22.18']
# ['Apron floodlighting', 'Spectral distribution of apron', '5.3.23.3']
# ['329.', 'floodlight']
# ['330.', 'Visual docking', 'Application', '5.3.24.1']
# ['331.', 'guidance system', 'Application after 01 January 2005', '5.3.24.2']
# ['332.', 'Characteristics', '5.3.24.3']
# ['333.', 'Functioning under all conditions', '5.3.24.4']
# ['334.', 'Indication for malfunctioning', '5.3.24.5']
# ['335.', 'Location of the system', '5.3.24.6']
# ['336.', 'Accuracy adapted to each bridge', '5.3.24.7']
# ['337.', 'Identification of the selected aircraft', '5.3.24.9']
# ['338.', 'Azimuth guidance unit location', '5.3.24.10']
# ['339.', 'Guidance information', '5.3.24.12']
# ['340.', 'Guidance color', 'green and red', '5.3.24.13']
# ['341.', 'Stopping position', 'Location', '5.3.24.14']
# ['342.', 'indicator', 'Visible from the left seat', '5.3.24.15']
# []
# []
# ['Indication closing speed', '5.3.24.18']
# ['Green to go ahead', 'red to stop', '5.3.24.20']
# ['Advanced visual', 'Color red', 'fix', 'unidirectional', '5.3.25.5']
# ['docking guidance', 'Guidance information', '5.3.25.6']
# ['system', 'Info available for all aft taxi speed', '5.3.25.7']
# ['Time of display not to allow', '5.3.25.8']
# ['displacement of more than 1 meter']
# ['Symbols & graphics to be intuitive', '5.3.25.10']
# ['Time for communicating lateral', '5.3.25.11']
# ['displacement']
# ['Closure distance and closure rate', '15', '5.3.25.12']
# ['meter prior to stop position']
# ['Emergency stop device', '5.3.25.14']
# ['Emergency stop for operating staff', '5.3.25.15']
# ['Aircraft stand', 'Location', '5.3.26.2']
# ['manoeuvring', 'Characteristics: colors', '5.3.26.3']
# ['guidance lights', 'Stop position : fix', 'unidirectional', 'red', '5.3.26.5']
# ['Road-holding position', 'Mandatory if RVR less than 350 m', '5.3.27.1']
# ['light', 'Location', '5.3.27.3']
# ['Characteristic composition', '5.3.27.4']
# ['Unidirectional', 'visible when approach', '5.3.27.5']
# ['holding position']
# ['Intensity of the light beam', '5.3.27.6']
# ['Flash frequency', 'between 30 & 60 per', '5.3.27.7']
# ['minute']
# ['5.4 Signs', 'Application : mandatory instructions', '5.4.1.1']
# ['info on location Etc.']
# ['Characteristics Frangible', 'low', '5.4.1.3']
# ['dimension & height', 'Tableau 5-5']
# ['Rectangular signs', 'Fig. 5-29& 5-30', '5.4.1.4']
# ['Red for mandatory instruction sign', '5.4.1.5']
# ['only']
# ['368.', 'Inscription Appendix', '5.4.1.6']
# ['369.', 'Illuminated signs', 'see conditions', '5.4.1.7']
# ['370.', 'Retro reflective code 1 et 2', 'non-', '5.4.1.8']
# ['instrument rwy']
# ['Panel variable message', 'white when', '5.4.1.9']
# ['371.', 'not used']
# ['372.', 'Panel variable message', 'no', '5.4.1.10']
# ['message if out of service']
# ['373.', 'Mandatory instruction', 'Authorization to go ahead', '5.4.2.1']
# ['374.', 'sign', 'Content of mandatory instruction sign', '5.4.2.2']
# ['Intersection rwy/twy & rwy/rwy. Pattern', '5.4.2.3']
# ['375.', 'A']
# ['376.', 'Rwy holding position for Cat I', 'II or III.', '5.4.2.4']
# ['Pattern B']
# ['377.', 'Sign to be installed with marking', '5.4.2.5']
# ['378.', 'No Entry sign', '5.4.2.7']
# ['379.', 'Location', '5.4.2.8']
# ['380.', 'Location - other', '5.4.2.9']
# ['381.', 'Location - other', '5.4.2.10']
# ['382.', 'Location - other', '5.4.2.11']
# ['Characteristics: mandatory = white on', '5.4.2.12']
# ['383.', 'red background']
# ['384.', 'Characteristics. : runway designation', '5.4.2.14']
# ['385.', 'Characteristics: designation Cat I', 'II', '5.4.2.15']
# ['et III']
# ['386.', 'Characteristics: No Entry sign', 'Fig. 5-', '5.4.2.16']
# ['29']
# ['Characteristics." \'rwy holding sign', 'tu', '5.4.2.17']
# ['387.', 'design and a number"']
# ['388.', 'Characteristics: symbols', '5.4.2.18']
# ['389.', 'Information signs', 'Application', '5.4.3.1']
# ['390.', 'Information signs to include', '5.4.3.2']
# ['Runway vacated sign', '5.4.3.4']
# ['Sign at intersection TWY', '5.4.3.7']
# ['Direction sign intersection twy/twy', '5.4.3.8']
# ['Location sign with rwy designation', '5.4.3.10']
# ['Location sign with direction sign', '5.4.3.11']
# ['Location : left side of Twy', 'see except.', '5.4.3.14']
# ['Location: information sign', '5.4.3.15']
# ['Location: Rwy exit sign same side as', '5.4.3.16']
# ['twy']
# ['Location : Rwy exit sign', '60 m before', '5.4.3.17']
# ['tangency point']
# ['Location: Rwy vacated sign', '5.4.3.18']
# ['Location: combined sign', 'vacated rwy', '5.4.3.19']
# ['& twy location']
# ['Location: intersection take-off sign', '5.4.3.20']
# ['Positioning : Sign twy location with', '5.4.3.21']
# ['rwy designation']
# ['Information sign colourcoted with', '5.4.3.23']
# ['mandatory sign']
# ['Characteristics (C): information sign', '5.4.3.25']
# ['black on yellow background except for']
# ['location sign']
# ['Location sign= yellow on black', '5.4.3.26']
# ['background']
# ['C: Rwy exit = twy designator + arrow', '5.4.3.27']
# ['for direction']
# ['C Content rwy vacated sign', 'fig. 5-', '5.4.3.28']
# ['29', 'A']
# ['C: Take-off sign', '5.4.3.29']
# ['C: Inscription on destination sign', '5.4.3.30']
# ['C: Inscription on direction pane', '5.4.3.31']
# ['413.', 'C: Inscription on location sign', '5.4.3.32']
# ['C: Location & direction panels co-', '5.4.3.34']
# ['414.', 'located']
# ['C: Identification of twy: letter with', '5.4.3.35']
# ['415.', 'number']
# ['C: Number only on manoeuvring area', '5.4.3.37']
# ['416.', '= for rwy designation']
# ['417.', 'VOR Aerodrome', 'If VOR checkpoint is established', 'it', '5.4.4.1']
# ['Checkpoint Sign', 'must be indicated with marking']
# ['418.', 'Location', '5.4.4.2']
# ['419.', 'Colour', '5.4.4.3']
# ['Airport Identification', 'Name of the aerodrome', '5.4.5.3']
# ['420.', 'sign']
# ['421.', 'Road-holding position', 'Installed everywhere road lead to rwy', '5.4.7.1']
# ['422.', 'sign', 'Location', '5.4.7.2']
# ['423.', 'White on red background', '5.4.7.3']
# ['424.', 'National language', '5.4.7.4']
# ['425.', 'llluminated if use at night', '5.4.7.5']
# ['426.', '5.5 Markers', 'Frangible and low', '5.5.1']
# ['427. 428.', 'Stop way edge marker different from rwy edge marker', '5.5.3.2']
# ['429. 430.', 'Twy edge marker E retro reflective blue', '5.5.5.3']
# ['431.', 'Twy edge marker = frangible & low', '5.5.5.5']
# ['432. 433.', 'Twy centre line marker = retro reflective green', '5.5.6.5']
# ['434. 435.', 'Twy centre line marker', 'designed to support aircraft weight', '5.5.6.7']
# ['436. 437.', 'Boundary markers used when there is no rwy', '5.5.8.1']
# ['438.', 'Location', '5.5.8.2']
# ['439.', '6.1 Objects to be', 'Fixe object +3000 m', 'approach or', '6.1.3']
# ['and/or', 'transitional surface shall be marked or']
# ['lighted']
# ['Fixe object above obstacle protection', '6.1.5']
# ['surface = marked or lighted']
# ['Marks for vehicles', '6.1.6']
# ['Mark for elevated aeronautical ground', '6.1.7']
# ['lights']
# ['Obstacles', 'Ref. distance table 3-1', '6.1.8']
# ['shall be marked or lighted']
# ['of', 'Fixe objects to be colored or marked', '6.2.1']
# ['Mobile objects colored or flags', '6.2.2']
# ['Use of markers', '6.2.7']
# ['Use of flags', '6.2.11']
# ['Design of flags for fix objects', '6.2.12']
# ['Design of flags for mobile objects', '6.2.14']
# ['of', 'Low', 'medium or high intensity', '6.3.1']
# ['Obstacle light for vehicles & mobile', '6.3.4']
# ['objects = Type C']
# ['Obstacle light for <<FOLLOW ME >)', '6.3.5']
# ['vehicle = type D']
# ['Obstacle light at top of obstacle', '6.3.11']
# ['Special cases', 'pylons etc.', '6.3.13']
# ['Special cases', 'extensive or closely', '6.3.14']
# ['spaced objects']
# ['Special cases', '+ 105 metres above', '6.3.16']
# ['surrounding ground']
# ['Idem', 'more than 45 metres', '6.3.17']
# ['Idem', '6.3.18']
# ['Special cases : to see', '6.3.19']
# ['Special case', 'height', 'type of lights', '6.3.20']
# ['etc.']
# ['Light on fix object = fix red light', '6.3.23']
# ['462.', 'tableau']
# ['463.', 'Obstacle light low intens', 'type A & B', '6.3.24']
# ['spec table 6-3']
# ['Obstacle light on emergency vehicle =', '6.3.25']
# ['464.', 'flashing blue']
# ['Obstacle light on FOLLOW ME E', '6.3.26']
# ['465.', 'flashing yellow']
# ['466.', 'Obstacle light low intens', 'type C and', '6.3.27']
# ['table 6-3']
# ['467.', 'Obstacles light on bridge E fix red', '6.3.28']
# ['Obstacle light on object with limited', '6.3.29']
# ['468.', 'mobility conform type A', 'table 6-3']
# ['Obstacle light', 'definition type A et B', '6.3.30']
# ['469.', 'et C: couleurs']
# ['470.', 'Obstacle light types A', 'B', 'C table 6-3', '6.3.31']
# ['471.', 'Obstacle light', 'medium intens', 'type A', '6.3.32']
# ['& B = flashing simultaneously']
# ['472.', 'HI Obstacle light types A & B =', '6.3.33']
# ['flashing white']
# ['473.', 'Obstacle light HI', 'types A & B', '6.3.34']
# ['conform table 6-3']
# ['474.', 'Obstacle light HI', 'type A on object =', '6.3.35']
# ['flash simultaneously']
# ['6.4 Wind Turbines', 'Wind turbines shall be marked and/or', '6.4.1']
# ['475.', 'lighted if it constitutes an obstacle']
# ['476.', '7.1 Closed runways', 'Application', '7.1.1']

# %%
master_list[0][1]
# Out:
# 'STANDARDS'

# %%
dup = []
for i in range(len(master_list)):
    if len(master_list[i])>=2:
        dup.append(master_list[i])
        
for i in dup:
    print(i)
# Out:
# ['ITEMS', 'STANDARDS', 'REF ANN. 14', 'C', 'N C', 'N/A', 'COMMENTS']
# ['3.1 Runways', 'RWY surfaces WIO irregularities', '3.1.22']
# ['RWY', 'friction characteristics on wet', '3.1.23']
# ['3.2 Runway', 'No standard']
# ['3.3 Runway Turn', 'Application for code D', 'E or F', '3.3.1']
# ['Pads', 'Runway turn pad - design', '3.3.6']
# ['Surface of RWY turn pads', '3.3.10']
# ['3.4 Runway Strips', 'General - RWY and stop way included in', '3.4.1']
# ['Length of rwy strip', '3.4.2']
# ['Width of rwy strip', '3.4.3']
# ['Objects on rwy strip', '3.4.7']
# ['Junction rwy and other surfaces', '3.4.10']
# ['3.5 Runway End', 'General - mandatory depending on runway', '3.5.1']
# ['Safety Area (RESA)', 'code']
# ['Dimensions', 'length', '3.5.2']
# ['Dimensions width', '3.5.4']
# ['3.6 Clearways', 'No standard']
# ['3.7 Stop ways', 'Width', '3.7.1']
# ['3.8 Radio Altimeter', 'No standard']
# ['20.', '3.9 Taxiways', 'Clearances', 'design', '3.9.4']
# ['21.', 'Taxiways on bridge', '3.9.20']
# ['22.', '3.10 Taxiway', 'No standard']
# ['23.', '3.11 TWY strips', 'Twy included in a strip', '3.11.1']
# ['24.', '3.12 Holding bays', 'Establishment criteria rwy-holding position', '3.12.2']
# ['rwy-holding', 'Establishment criteria rwy-holding position', '3.12.3']
# ['25.', 'positions', 'to protect navaids']
# ['26.', 'intermediate holding', 'Road-holding position - rwy', '3.12.5']
# ['27.', 'positions', 'road-', 'Location of above signs', '3.12.6']
# ['28.', 'holding positions', 'RWY holding position & ILS protection', '3.12.9']
# ['29.', '3.13 Apron', 'No standard']
# ['30.', '3.14 Isolated aircraft', 'Identification of an isolated aircraft parking', '3.14.1']
# ['parking position', 'position']
# ['31.', '3.15 De-icing', 'No standard']
# ['32', '4.1 Obstacle', 'Conical surface', 'description', 'GSR 751']
# ['33.', 'Limitation Surfaces', 'Conical surface', 'characteristics', 'GSR 751']
# ['34.', 'Conical surface', 'slopes', 'GSR 751']
# ['35.', 'Inner horizonta', 'Description', 'GSR 751']
# ['36.', 'surface', 'Characteristics', 'GSR 751']
# ['37.', 'Height', 'method of measurement', 'GSR 751']
# ['38.', 'Approach surface', 'Description', 'GSR 751']
# ['39.', 'Characteristics', 'GSR 751']
# ['40.', 'Elevation of inner edge', 'GSR 751']
# ['41.', 'Slope of approach surface', 'GSR 751']
# ['42.', 'Inner approach', 'Description', 'GSR 751']
# ['44.', 'Transitional surface', 'Description', 'GSR 751']
# ['45.', 'Characteristics', 'GSR 751']
# ['46.', 'Elevation', 'GSR 751']
# ['47.', 'Slopes', 'GSR 751']
# ['48.', 'Inner transitional', 'Description', 'GSR 751']
# ['49.', 'surface', 'Characteristics', 'GSR 751']
# ['50.', 'Elevation', 'GSR 751']
# ['51.', 'Slopes', 'GSR 751']
# ['52.', 'Balked landing', 'Description', 'GSR 751']
# ['53.', 'surface', 'Characteristics', 'GSR 751']
# ['54.', 'Elevation', 'GSR 751']
# ['55.', 'Slopes', 'GSR 751']
# ['56.', 'Take-off climb', 'Description', 'GSR 751']
# ['57.', 'surface', 'Characteristics', 'GSR 751']
# ['58.', 'Elevationof inner edge', 'GSR 751']
# ['59.', 'Take-off flight path', 'Measurement -A', 'GSR 751']
# ['60.', 'Measurement - - B', 'GSR 751']
# ['61.', '4.2 Obstacle', 'Obstacle limitations depending on the', 'GSR 751']
# ['limitation', 'type of surface', 'GSR 751']
# ['requirements - No-', 'Height and slope of various types of', 'GSR 751']
# ['62.', 'instrument runways', 'surface', 'GSR 751']
# ['63', 'New objects or extension of existing', 'GSR 751']
# ['objects', 'GSR 751']
# ['Obstacle limitation', 'Obstacle limitations depending on the', 'GSR 751']
# ['64.', 'requirements-no', 'type of surface', 'GSR 751']
# ['65', 'precision approach', 'Height and slope of surfaces - A', 'GSR 751']
# ['66.', 'runway', 'Height and slope of surfaces - B', 'GSR 751']
# ['67.', 'New objects or extension of existing', 'GSR 751']
# ['68.', 'Obstacle limitation', 'Types of surfaces. CAT I', 'GSR 751']
# ['69.', 'requirements', 'Types of surfaces. CAT II and III', 'GSR 751']
# ['70.', 'precision approach', 'Height & slope of surfaces - A', 'GSR 751']
# ['71.', 'runway', 'Height & slopes of surfaces - B', 'GSR 751']
# ['72.', 'Fixed objects above surfaces', 'GSR 751']
# ['New objects or extension of existing', 'GSR 751']
# ['73.', 'objects', 'GSR 751']
# ['74.', 'Runways meant for', 'Type of obstacle limitation surface', 'GSR 751']
# ['75.', 'take-off', 'Dimensions of surfaces', 'GSR 751']
# ['New objects or extension of existing', 'GSR 751']
# ['76.', 'objects']
# ['77.', '5.1 -Indicators and']
# ['78.', 'Wind direction', 'Availability', '5.1.1.1']
# ['79.', 'indicator', 'Location', '5.1.1.2']
# ['80.', 'Landing direction', 'Availability', '5.1.2.1']
# ['81.', 'indicator', 'Location', '5.1.2.3']
# ['82.', 'Signalling lamp', 'Application', '5.1.3.1']
# ['Signal panels &', 'Characteristics of signal area', '5.1.4.2']
# ['83.', 'signal area']
# ['84.', '5.2 Markings']
# ['85.', 'Generals', 'General', 'interruption of runway', '5.2.1.1']
# ['86.', 'Interruption intersection rwy and twy', '5.2.1.3']
# ['87.', 'Color and conspicuity', 'RWY marking - White', '5.2.1.4']
# ['88.', 'TWY and other marking Yellow', '5.2.1.5']
# ['89.', 'Apron safety lines conspicuous', '5.2.1.6']
# ['90.', 'Runway designation', 'Marking at threshold', '5.2.2.1']
# ['91.', 'marking', 'Location of marking', '5.2.2.3']
# ['92.', 'Characteristics', '5.2.2.4']
# ['93.', 'Marking parallel runways', '5.2.2.5']
# ['94.', 'Proportions numbers and letters', '5.2.2.6']
# ['95.', 'Runway center line', 'Application', '5.2.3.1']
# ['96.', 'marking', 'Location', '5.2.3.2']
# ['97.', 'Characteristics', '5.2.3.3']
# ['98', 'Width of stripes', '5.2.3.4']
# ['100.', 'Location', '5.2.4.4']
# ['101.', 'Characteristics', '5.2.4.5']
# ['102.', 'Surface to be covered', '5.2.4.6']
# ['103.', 'Transverse stripe', 'Stripe width', '5.2.4.8']
# ['104.', 'Arrows', 'Permanently displaced threshold', '5.2.4.9']
# ['105.', 'Temporarily displaced threshold', '5.2.4.10']
# ['106.', 'Aiming point marking', 'Application', '5.2.5.1']
# ['107.', 'Use according with runway code', '5.2.5.2']
# ['108.', 'Location', '5.2.5.4']
# ['109.', 'Characteristics', '5.2.5.5']
# ['110.', 'Touchdown zone', 'Application', '5.2.6.1']
# ['111.', 'marking', 'Location and Characteristics', '5.2.6.3']
# ['112.', 'Configuration A et B', '5.2.6.4']
# ['113.', 'Runway side stripe', 'Application', '5.2.7.1']
# ['114.', 'Taxiway centre line', 'Application', '5.2.8.1']
# ['115.', 'marking', 'Standard taxi-route marking', '5.2.8.3']
# ['116.', 'Enhanced taxiway centre line marking', '5.2.8.5']
# ['117.', 'Location', 'enhanced marking', '5.2.8.9']
# ['118.', 'Characteristics - enhanced marking', '5.2.8.10']
# ['119.', 'Characteristics - figure 5-7', '5.2.8.11']
# ['120.', 'Runway turn pad', 'Application', '5.2.9.1']
# ['121.', 'marking', 'Characteristics', '5.2.9.7']
# ['122.', 'Runway-holding', 'Application and Location', '5.2.10.1']
# ['123.', 'position marking', 'Characteristics', '5.2.10.2']
# ['124.', 'Holding point Cat I', 'II and III', '5.2.10.3']
# ['125.', 'Runway-holding position', 'pattern A', '5.2.10.4']
# ['126.', 'Runway-holding position', 'runway', '5.2.10.7']
# ['intersection', 'pattern A']
# ['127.', 'Intermediate holding', 'Intersection - 2 taxiways', '5.2.11.3']
# ['128.', 'position marking', 'Distance between holding position', '5.2.11.4']
# ['129.', 'Characteristics', '5.2.11.5']
# ['130.', 'VOR Airport', 'Application', '5.2.12.1']
# ['131.', 'checkpoint marking', 'Site Selection', '5.2.12.2']
# ['132.', 'Location', '5.2.12.3']
# ['133.', 'Characteristics', '5.2.12.4']
# ['134.', 'Aircraft stand mark', 'No standard']
# ['135.', 'Apron safety line', 'Location', '5.2.14.2']
# ['136.', 'Road-holding position', 'Application', '5.2.15.1']
# ['137.', 'marking', 'Location', '5.2.15.2']
# ['138.', 'Characteristics local traffic regulation', '5.2.15.3']
# ['139.', 'Mandatory instruction', 'Application', '5.2.16.1']
# ['140.', 'marking', 'Location', 'code letter A', 'B', 'C and D', '5.2.16.3']
# ['141.', 'Location', 'code letter E and F', '5.2.16.4']
# ['142.', 'Characteristics - No entry.', '5.2.16.6']
# ['143.', 'Characteristics - No entry', 'colors', '5.2.16.7']
# ['144.', 'Characteristics - Conspicuity', '5.2.16.8']
# ['145.', 'Information marking', 'Application', '5.2.17.1']
# ['146.', 'Characteristics', '5.2.17.6']
# ['147.', 'Conspicuity', '5.2.17.7']
# ['148.', '5.3 Lights']
# ['General', 'Lights which may endanger safety of', '5.3.1.1']
# ['149.', 'aircraft']
# ['150.', 'Elevated approach', 'Frangibility', '5.3.1.4']
# ['151.', 'lights', '5.3.1.4 applicable after January 1', '5.3.1.5']
# ['152.', 'Marking for conspicuity', '5.3.1.6']
# ['153.', 'Elevated lights', 'Frangibility and clearance for', '5.3.1.7']
# ['154.', 'Surface lights', 'Design', '5.3.1.8']
# ['155.', 'Light intensity and', 'Intensity for visibility', '5.3.1.10']
# ['156.', 'control', 'Intensity control', '5.3.1.11']
# ['157.', 'Intensity maximum A', '5.3.1.12']
# ['158.', 'Intensity maximum B', '5.3.1.13']
# ['Aeronautical beacons', 'If operationally required', '5.3.3.1']
# ['Requirements for establishing', '5.3.3.2']
# ['Airport beacons', 'Conditions to have a beacon', '5.3.3.3']
# ['Location', '5.3.3.4']
# ['Characteristics', '5.3.3.6']
# ['Visibility angles', '5.3.3.7']
# ['dentification beacon', 'Application', '5.3.3.8']
# ['Location', '5.3.3.9']
# ['Characteristics', '5.3.3.11']
# ['Colour of flashing lights', '5.3.3.12']
# ['Identification', 'Morse code', '5.3.3.13']
# ['Approach lighting', 'Application', 'non-instrument RWY', '5.3.4.1']
# ['system', 'Application non-precision approach', '5.3.4.1']
# ['Application', 'Precision approach', '5.3.4.1']
# ['Application', 'Precision approach', '5.3.4.1']
# ['Simple approach', 'Location', '5.3.4.2']
# ['lighting system', 'Position of lights on crossbar', '5.3.4.3']
# ['Centre line lights', '5.3.4.4']
# ['Position of the system - plane to thld', '5.3.4.6']
# ['Characteristics', '5.3.4.7']
# ['Precision approach', 'Location', '5.3.4.10']
# ['CAT I lighting system', 'Position - runway centre line', '5.3.4.11']
# ['Centre line - space between lights', '5.3.4.12']
# ['Position of the system - horizontal', '5.3.4.13']
# ['Characteristics - fixed lights showing', '5.3.4.14']
# ['Serviceability level', '5.3.4.15']
# ['Barrettes - light spacing', '5.3.4.16']
# ['Number of flashes per second.', '5.3.4.18']
# ['Additional lights on crossbar.', '5.3.4.19']
# ['Position of additional lights', '5.3.4.20']
# ['Lights conform to Appendix 2', 'Figure', '5.3.4.21']
# ['Precision approach', 'Location distance in the extended', '5.3.4.22']
# ['CAT II and III lighting', 'center line']
# ['system', 'Location longitudinal intervals', '5.3.4.23']
# ['Location - on barrettes', '5.3.4.24']
# ['Crossbar at 150 meters', '5.3.4.25']
# ['Crossbar at 300 meters', '5.3.4.26']
# ['Additional crossbars', '5.3.4.27']
# ['Position of lights on additional', '5.3.4.28']
# ['Position horizontal plan', '5.3.4.29']
# ['Characteristics - for the first 300 m.', '5.3.4.30']
# ['Characteristics - over 300 meters', '5.3.4.31']
# ['Characteristics - Others', '5.3.4.32']
# ['Characteristics - Length of barrettes', '5.3.4.33']
# ['Characteristics - Flash per second', '5.3.4.35']
# ['Characteristics - Side row', 'color red', '5.3.4.36']
# ['Characteristics - Fixed lights', 'variable', '5.3.4.37']
# ['Characteristics - Compatibility', '5.3.4.38']
# ['Characteristics - Lights as per App 2', '5.3.4.39']
# ['Visual Approach', 'Application - Conditions for', '5.3.5.1']
# ['Slope Indicator', 'establishment']
# ['System', 'Application -']
# ['Application - Criteria for installation', '5.3.5.3']
# ['Application - Criteria for installation', '5.3.5.4']
# ['T-VASIS & AT-VASIS', 'description', '5.3.5.6']
# ['T-VASIS & AT-VASIS', 'description', '5.3.5.7']
# ['T-VASIS & AT-VASIS', 'description', '5.3.5.8']
# ['T-VASIS & AT-VASIS - Location', '5.3.5.9']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.10']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.11']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.12']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.13']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.14']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.15']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.16']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.17']
# ['Approach slope and', 'Approach slope appropriate for', '5.3.5.18']
# ['elevation settings of', 'aircraft using the approach']
# ['light beams', 'Visual approach slope conform', '5.3.5.19']
# ['Same setting', 'both end of runway', '5.3.5.20']
# ['Slope to clear all objects', '5.3.5.21']
# ['Adjustment of azimuth', '5.3.5.22']
# ['PAPI et APAPI', 'Description: PAPI', '5.3.5.23']
# ['Description: APAPI', '5.3.5.24']
# ['Description: PAPI position of red and', '5.3.5.25']
# ['Description: APAPI position of red', '5.3.5.26']
# ['Location: figure 5-18', '5.3.5.27']
# ['Characteristics: day and night', '5.3.5.28']
# ['Characteristics: others', '5.3.5.29']
# ['Characteristics: others', '5.3.5.30']
# ['Distribution light intensity', 'App. 2', '5.3.5.31']
# ['Intensity control', '5.3.5.32']
# ['Adjustment in elevation - limits', '5.3.5.33']
# ['Design to avoid accumulation of FOD', '5.3.5.34']
# ['Approach slope', 'figure 5-19', '5.3.5.35']
# ['Compatibility with ILS slope', '5.3.5.36']
# ['Slope angle to clear all objects.', '5.3.5.37']
# ['Same for APAP', '5.3.5.38']
# ['Azimuth spread of the light beam', '5.3.5.39']
# ['Same setting at both end of rwy', '5.3.5.40']
# ['Establishment of an obstacle', '5.3.5.41']
# ['Characteristic of the protection', '5.3.5.42']
# ['surface', 'Tableau 5-3 et fig. 5-20']
# ['New objects or extension of existing', '5.3.5.43']
# ['Removal of objects above obstacle', '5.3.5.44']
# ['Mitigation measures', '5.3.5.45']
# ['RWY lead-in lighting', 'No standard']
# ['RWY threshold', 'Location', '5.3.8.2']
# ['identification lights', 'Visible in the approach direction', '5.3.8.4']
# ['Runway edge lights', 'Application criteria', 'night operation or', '5.3.9.1']
# ['Location', '2 parallel row equidistant', '5.3.9.3']
# ['Location less than 3 metres from the', '5.3.9.4']
# ['Distance between lights', '60 or 100', '5.3.9.6']
# ['Characteristics: fix', 'white', 'variable', '5.3.9.7']
# ['Characteristics visible all angles', '5.3.9.8']
# ['Characteristics: 15 degrees above', '5.3.9.9']
# ['Characteristics: precision approach', '5.3.9.10']
# ['App 2', 'fig A2-9 and A2-10']
# ['Runway threshold', 'Application - RWY THLD Lights', '5.3.10.1']
# ['and wing bar lights', 'Location of lights at rwy end', '5.3.10.2']
# ['Location THLD lights', 'displaced thld', '5.3.10.3']
# ['Threshold: number of lights', '5.3.10.4']
# ['Wing bar thld lights', 'displaced thld', '5.3.10.7']
# ['Location of wing bar lights', '5.3.10.8']
# ['Characteristics: green', '5.3.10.9']
# ['Thld light', 'precision approach App. 2', '5.3.10.10']
# ['Thld wing bar light with precision', '5.3.10.11']
# ['Approach App 2', 'Fig. A2-4']
# ['Runway end lights', 'Mandatory for rwy equipped with edge', '5.3.11.1']
# ['Location', '5.3.11.2']
# ['275.', 'Characteristics: fix', 'unidirectional.', 'red', '5.3.11.4']
# ['Rwy end with precision approach', '5.3.11.5']
# ['276.', 'App 2', 'Fig A2-8']
# ['Runway Center Line', 'Mandatory for precision approach', '5.3.12.1']
# ['277.', 'Lights', 'CAT II and III']
# ['Mandatory for T/Off with RVR less', '5.3.12.3']
# ['278.', 'than 400 m.']
# ['279.', 'Location of lights', '5.3.12.5']
# ['Characteristics: fix', 'white', 'variable', '5.3.12.7']
# ['280.', 'intensity', 'etc.']
# ['Characteristics: accordance with', '5.3.12.8']
# ['281.', 'App. 2', 'Fig. A2-6 and A2-7']
# ['282.', 'Runway touchdown', 'Mandatory for precision approach Cat', '5.3.13.1']
# ['zone lights', 'II et III']
# ['283.', 'Location', '5.3.13.2']
# ['Characteristics: number of lights per', '5.3.13.3']
# ['284.', 'barrette and spacing']
# ['285.', 'Characteristics: fix', 'unidirectional', '5.3.13.5']
# ['white', 'variable']
# ['Accordance with spec. App 2', 'Fig. A2-', '5.3.13.6']
# ['286.', '5']
# ['287.', 'Rapid exit taxiway', 'Not to be on if pattern is not as fig 5-', '5.3.14.2']
# ['indicator lights', '24', 'in full.']
# ['288.', 'Located same side of the CL as the', '5.3.14.3']
# ['TWY', 'configur. Fig 5-23']
# ['289.', 'No overlapping when displayed', '5.3.14.4']
# ['Light yellow', 'unidirectional fix', '5.3.14.5']
# ['290.', 'visible direction approach.']
# ["Conform spec. 'App. 2", 'Fig. A2-6 or', '5.3.14.6']
# ['291.', 'A2-7']
# ['292.', 'if used at', '5.3.15.1']
# ['Location', '5.3.15.2']
# ['Characteristics', '5.3.15.3']
# ['Taxiway centre line', 'Mandatory is use with RVR less than', '5.3.16.1']
# ['lights', '350 m.']
# ['TWY lights on RWY if used as a', '5.3.16.4']
# ['Characteristics: green with reduced', '5.3.16.6']
# ['TWY lights on RWY exit shall be', '5.3.16.7']
# ['alternatively green & yellow', 'etc.']
# ['Conform Appendix 2', 'various figures', '5.3.16.8']
# ['Taxiway edge lights', 'Installed on rwy turn pas', 'holding bay', '5.3.17.1']
# ['and apron', 'etc. if used at night']
# ['Installed on rwy is part of taxi-route.', '5.3.17.2']
# ['Characteristics: blue', 'fix', 'visible 30', '5.3.17.7']
# ['Runway turn pad', 'Application', '5.3.18.1']
# ['lights', 'Light fix', 'unidirectional', 'green', '5.3.18.6']
# ['Conform spec. Appendices 2', 'Fig. A2-', '5.3.18.7']
# ['13', '14 ou 15']
# ['Stop bars', 'Mandatory if rwy use RVR les than', '5.3.19.1']
# ['350 m', 'etc.']
# ['Mandatory if rwy use with RVR', '5.3.19.2']
# ['Location', '5.3.19.5']
# ['Characteristics: Light red', 'spacing 3', '5.3.19.6']
# ['Characteristics: Rwy-holding position', '5.3.19.7']
# ['unidirectional', 'red', 'visible when']
# ['Additional lights as spec. 5.3.19.4', '5.3.19.8']
# ['switchable bars', '5.3.19.9']
# ['313.', 'App. 2', 'Fig.: Q2-12 to to16']
# ['314.', 'Electrical circuit: design', '5.3.19.13']
# ['315.', 'Intermediate holding', 'Conditions for installation', '5.3.20.1']
# ['316.', 'position lights', 'Location', '5.3.20.3']
# ['317.', 'Characteristics', '5.3.20.4']
# ['318.', 'De-icing/anti-icing', 'Location', '5.3.21.2']
# ['319.', 'facility exit lights', 'Characteristics', '5.3.21.3']
# ['320.', 'Runway Guard Lights', 'Application', '5.3.22.1']
# ['321.', 'Location configuration A', '5.3.22.4']
# ['322.', 'Location configuration B', '5.3.22.5']
# ['323.', 'Characteristics configuration A', '5.3.22.6']
# ['324.', 'Characteristics configuration B', '5.3.22.8']
# ['325.', 'Light beam definition', '5.3.22.9']
# ['326.', 'Lighting sequence light', 'confi. A', '5.3.22.16']
# ['327.', 'Lighting sequence light Config. B', '5.3.22.17']
# ['328.', 'Cycle 30 a 60 cycles per minute', '5.3.22.18']
# ['Apron floodlighting', 'Spectral distribution of apron', '5.3.23.3']
# ['329.', 'floodlight']
# ['330.', 'Visual docking', 'Application', '5.3.24.1']
# ['331.', 'guidance system', 'Application after 01 January 2005', '5.3.24.2']
# ['332.', 'Characteristics', '5.3.24.3']
# ['333.', 'Functioning under all conditions', '5.3.24.4']
# ['334.', 'Indication for malfunctioning', '5.3.24.5']
# ['335.', 'Location of the system', '5.3.24.6']
# ['336.', 'Accuracy adapted to each bridge', '5.3.24.7']
# ['337.', 'Identification of the selected aircraft', '5.3.24.9']
# ['338.', 'Azimuth guidance unit location', '5.3.24.10']
# ['339.', 'Guidance information', '5.3.24.12']
# ['340.', 'Guidance color', 'green and red', '5.3.24.13']
# ['341.', 'Stopping position', 'Location', '5.3.24.14']
# ['342.', 'indicator', 'Visible from the left seat', '5.3.24.15']
# ['Indication closing speed', '5.3.24.18']
# ['Green to go ahead', 'red to stop', '5.3.24.20']
# ['Advanced visual', 'Color red', 'fix', 'unidirectional', '5.3.25.5']
# ['docking guidance', 'Guidance information', '5.3.25.6']
# ['system', 'Info available for all aft taxi speed', '5.3.25.7']
# ['Time of display not to allow', '5.3.25.8']
# ['Symbols & graphics to be intuitive', '5.3.25.10']
# ['Time for communicating lateral', '5.3.25.11']
# ['Closure distance and closure rate', '15', '5.3.25.12']
# ['Emergency stop device', '5.3.25.14']
# ['Emergency stop for operating staff', '5.3.25.15']
# ['Aircraft stand', 'Location', '5.3.26.2']
# ['manoeuvring', 'Characteristics: colors', '5.3.26.3']
# ['guidance lights', 'Stop position : fix', 'unidirectional', 'red', '5.3.26.5']
# ['Road-holding position', 'Mandatory if RVR less than 350 m', '5.3.27.1']
# ['light', 'Location', '5.3.27.3']
# ['Characteristic composition', '5.3.27.4']
# ['Unidirectional', 'visible when approach', '5.3.27.5']
# ['Intensity of the light beam', '5.3.27.6']
# ['Flash frequency', 'between 30 & 60 per', '5.3.27.7']
# ['5.4 Signs', 'Application : mandatory instructions', '5.4.1.1']
# ['Characteristics Frangible', 'low', '5.4.1.3']
# ['dimension & height', 'Tableau 5-5']
# ['Rectangular signs', 'Fig. 5-29& 5-30', '5.4.1.4']
# ['Red for mandatory instruction sign', '5.4.1.5']
# ['368.', 'Inscription Appendix', '5.4.1.6']
# ['369.', 'Illuminated signs', 'see conditions', '5.4.1.7']
# ['370.', 'Retro reflective code 1 et 2', 'non-', '5.4.1.8']
# ['Panel variable message', 'white when', '5.4.1.9']
# ['371.', 'not used']
# ['372.', 'Panel variable message', 'no', '5.4.1.10']
# ['373.', 'Mandatory instruction', 'Authorization to go ahead', '5.4.2.1']
# ['374.', 'sign', 'Content of mandatory instruction sign', '5.4.2.2']
# ['Intersection rwy/twy & rwy/rwy. Pattern', '5.4.2.3']
# ['375.', 'A']
# ['376.', 'Rwy holding position for Cat I', 'II or III.', '5.4.2.4']
# ['377.', 'Sign to be installed with marking', '5.4.2.5']
# ['378.', 'No Entry sign', '5.4.2.7']
# ['379.', 'Location', '5.4.2.8']
# ['380.', 'Location - other', '5.4.2.9']
# ['381.', 'Location - other', '5.4.2.10']
# ['382.', 'Location - other', '5.4.2.11']
# ['Characteristics: mandatory = white on', '5.4.2.12']
# ['383.', 'red background']
# ['384.', 'Characteristics. : runway designation', '5.4.2.14']
# ['385.', 'Characteristics: designation Cat I', 'II', '5.4.2.15']
# ['386.', 'Characteristics: No Entry sign', 'Fig. 5-', '5.4.2.16']
# ['Characteristics." \'rwy holding sign', 'tu', '5.4.2.17']
# ['387.', 'design and a number"']
# ['388.', 'Characteristics: symbols', '5.4.2.18']
# ['389.', 'Information signs', 'Application', '5.4.3.1']
# ['390.', 'Information signs to include', '5.4.3.2']
# ['Runway vacated sign', '5.4.3.4']
# ['Sign at intersection TWY', '5.4.3.7']
# ['Direction sign intersection twy/twy', '5.4.3.8']
# ['Location sign with rwy designation', '5.4.3.10']
# ['Location sign with direction sign', '5.4.3.11']
# ['Location : left side of Twy', 'see except.', '5.4.3.14']
# ['Location: information sign', '5.4.3.15']
# ['Location: Rwy exit sign same side as', '5.4.3.16']
# ['Location : Rwy exit sign', '60 m before', '5.4.3.17']
# ['Location: Rwy vacated sign', '5.4.3.18']
# ['Location: combined sign', 'vacated rwy', '5.4.3.19']
# ['Location: intersection take-off sign', '5.4.3.20']
# ['Positioning : Sign twy location with', '5.4.3.21']
# ['Information sign colourcoted with', '5.4.3.23']
# ['Characteristics (C): information sign', '5.4.3.25']
# ['Location sign= yellow on black', '5.4.3.26']
# ['C: Rwy exit = twy designator + arrow', '5.4.3.27']
# ['C Content rwy vacated sign', 'fig. 5-', '5.4.3.28']
# ['29', 'A']
# ['C: Take-off sign', '5.4.3.29']
# ['C: Inscription on destination sign', '5.4.3.30']
# ['C: Inscription on direction pane', '5.4.3.31']
# ['413.', 'C: Inscription on location sign', '5.4.3.32']
# ['C: Location & direction panels co-', '5.4.3.34']
# ['414.', 'located']
# ['C: Identification of twy: letter with', '5.4.3.35']
# ['415.', 'number']
# ['C: Number only on manoeuvring area', '5.4.3.37']
# ['416.', '= for rwy designation']
# ['417.', 'VOR Aerodrome', 'If VOR checkpoint is established', 'it', '5.4.4.1']
# ['Checkpoint Sign', 'must be indicated with marking']
# ['418.', 'Location', '5.4.4.2']
# ['419.', 'Colour', '5.4.4.3']
# ['Airport Identification', 'Name of the aerodrome', '5.4.5.3']
# ['420.', 'sign']
# ['421.', 'Road-holding position', 'Installed everywhere road lead to rwy', '5.4.7.1']
# ['422.', 'sign', 'Location', '5.4.7.2']
# ['423.', 'White on red background', '5.4.7.3']
# ['424.', 'National language', '5.4.7.4']
# ['425.', 'llluminated if use at night', '5.4.7.5']
# ['426.', '5.5 Markers', 'Frangible and low', '5.5.1']
# ['427. 428.', 'Stop way edge marker different from rwy edge marker', '5.5.3.2']
# ['429. 430.', 'Twy edge marker E retro reflective blue', '5.5.5.3']
# ['431.', 'Twy edge marker = frangible & low', '5.5.5.5']
# ['432. 433.', 'Twy centre line marker = retro reflective green', '5.5.6.5']
# ['434. 435.', 'Twy centre line marker', 'designed to support aircraft weight', '5.5.6.7']
# ['436. 437.', 'Boundary markers used when there is no rwy', '5.5.8.1']
# ['438.', 'Location', '5.5.8.2']
# ['439.', '6.1 Objects to be', 'Fixe object +3000 m', 'approach or', '6.1.3']
# ['and/or', 'transitional surface shall be marked or']
# ['Fixe object above obstacle protection', '6.1.5']
# ['Marks for vehicles', '6.1.6']
# ['Mark for elevated aeronautical ground', '6.1.7']
# ['Obstacles', 'Ref. distance table 3-1', '6.1.8']
# ['of', 'Fixe objects to be colored or marked', '6.2.1']
# ['Mobile objects colored or flags', '6.2.2']
# ['Use of markers', '6.2.7']
# ['Use of flags', '6.2.11']
# ['Design of flags for fix objects', '6.2.12']
# ['Design of flags for mobile objects', '6.2.14']
# ['of', 'Low', 'medium or high intensity', '6.3.1']
# ['Obstacle light for vehicles & mobile', '6.3.4']
# ['Obstacle light for <<FOLLOW ME >)', '6.3.5']
# ['Obstacle light at top of obstacle', '6.3.11']
# ['Special cases', 'pylons etc.', '6.3.13']
# ['Special cases', 'extensive or closely', '6.3.14']
# ['Special cases', '+ 105 metres above', '6.3.16']
# ['Idem', 'more than 45 metres', '6.3.17']
# ['Idem', '6.3.18']
# ['Special cases : to see', '6.3.19']
# ['Special case', 'height', 'type of lights', '6.3.20']
# ['Light on fix object = fix red light', '6.3.23']
# ['462.', 'tableau']
# ['463.', 'Obstacle light low intens', 'type A & B', '6.3.24']
# ['Obstacle light on emergency vehicle =', '6.3.25']
# ['464.', 'flashing blue']
# ['Obstacle light on FOLLOW ME E', '6.3.26']
# ['465.', 'flashing yellow']
# ['466.', 'Obstacle light low intens', 'type C and', '6.3.27']
# ['467.', 'Obstacles light on bridge E fix red', '6.3.28']
# ['Obstacle light on object with limited', '6.3.29']
# ['468.', 'mobility conform type A', 'table 6-3']
# ['Obstacle light', 'definition type A et B', '6.3.30']
# ['469.', 'et C: couleurs']
# ['470.', 'Obstacle light types A', 'B', 'C table 6-3', '6.3.31']
# ['471.', 'Obstacle light', 'medium intens', 'type A', '6.3.32']
# ['472.', 'HI Obstacle light types A & B =', '6.3.33']
# ['473.', 'Obstacle light HI', 'types A & B', '6.3.34']
# ['474.', 'Obstacle light HI', 'type A on object =', '6.3.35']
# ['6.4 Wind Turbines', 'Wind turbines shall be marked and/or', '6.4.1']
# ['475.', 'lighted if it constitutes an obstacle']
# ['476.', '7.1 Closed runways', 'Application', '7.1.1']

# %%
try_dict = {}
for i in range(len(dup)):
    value = ""
    print(dup[i])
    for j in dup[i][1:]:
        value+= "," + j
    try_dict[dup[i][0]] = value
    
    
print(try_dict)
# Out:
# ['ITEMS', 'STANDARDS', 'REF ANN. 14', 'C', 'N C', 'N/A', 'COMMENTS']
# ['3.1 Runways', 'RWY surfaces WIO irregularities', '3.1.22']
# ['RWY', 'friction characteristics on wet', '3.1.23']
# ['3.2 Runway', 'No standard']
# ['3.3 Runway Turn', 'Application for code D', 'E or F', '3.3.1']
# ['Pads', 'Runway turn pad - design', '3.3.6']
# ['Surface of RWY turn pads', '3.3.10']
# ['3.4 Runway Strips', 'General - RWY and stop way included in', '3.4.1']
# ['Length of rwy strip', '3.4.2']
# ['Width of rwy strip', '3.4.3']
# ['Objects on rwy strip', '3.4.7']
# ['Junction rwy and other surfaces', '3.4.10']
# ['3.5 Runway End', 'General - mandatory depending on runway', '3.5.1']
# ['Safety Area (RESA)', 'code']
# ['Dimensions', 'length', '3.5.2']
# ['Dimensions width', '3.5.4']
# ['3.6 Clearways', 'No standard']
# ['3.7 Stop ways', 'Width', '3.7.1']
# ['3.8 Radio Altimeter', 'No standard']
# ['20.', '3.9 Taxiways', 'Clearances', 'design', '3.9.4']
# ['21.', 'Taxiways on bridge', '3.9.20']
# ['22.', '3.10 Taxiway', 'No standard']
# ['23.', '3.11 TWY strips', 'Twy included in a strip', '3.11.1']
# ['24.', '3.12 Holding bays', 'Establishment criteria rwy-holding position', '3.12.2']
# ['rwy-holding', 'Establishment criteria rwy-holding position', '3.12.3']
# ['25.', 'positions', 'to protect navaids']
# ['26.', 'intermediate holding', 'Road-holding position - rwy', '3.12.5']
# ['27.', 'positions', 'road-', 'Location of above signs', '3.12.6']
# ['28.', 'holding positions', 'RWY holding position & ILS protection', '3.12.9']
# ['29.', '3.13 Apron', 'No standard']
# ['30.', '3.14 Isolated aircraft', 'Identification of an isolated aircraft parking', '3.14.1']
# ['parking position', 'position']
# ['31.', '3.15 De-icing', 'No standard']
# ['32', '4.1 Obstacle', 'Conical surface', 'description', 'GSR 751']
# ['33.', 'Limitation Surfaces', 'Conical surface', 'characteristics', 'GSR 751']
# ['34.', 'Conical surface', 'slopes', 'GSR 751']
# ['35.', 'Inner horizonta', 'Description', 'GSR 751']
# ['36.', 'surface', 'Characteristics', 'GSR 751']
# ['37.', 'Height', 'method of measurement', 'GSR 751']
# ['38.', 'Approach surface', 'Description', 'GSR 751']
# ['39.', 'Characteristics', 'GSR 751']
# ['40.', 'Elevation of inner edge', 'GSR 751']
# ['41.', 'Slope of approach surface', 'GSR 751']
# ['42.', 'Inner approach', 'Description', 'GSR 751']
# ['44.', 'Transitional surface', 'Description', 'GSR 751']
# ['45.', 'Characteristics', 'GSR 751']
# ['46.', 'Elevation', 'GSR 751']
# ['47.', 'Slopes', 'GSR 751']
# ['48.', 'Inner transitional', 'Description', 'GSR 751']
# ['49.', 'surface', 'Characteristics', 'GSR 751']
# ['50.', 'Elevation', 'GSR 751']
# ['51.', 'Slopes', 'GSR 751']
# ['52.', 'Balked landing', 'Description', 'GSR 751']
# ['53.', 'surface', 'Characteristics', 'GSR 751']
# ['54.', 'Elevation', 'GSR 751']
# ['55.', 'Slopes', 'GSR 751']
# ['56.', 'Take-off climb', 'Description', 'GSR 751']
# ['57.', 'surface', 'Characteristics', 'GSR 751']
# ['58.', 'Elevationof inner edge', 'GSR 751']
# ['59.', 'Take-off flight path', 'Measurement -A', 'GSR 751']
# ['60.', 'Measurement - - B', 'GSR 751']
# ['61.', '4.2 Obstacle', 'Obstacle limitations depending on the', 'GSR 751']
# ['limitation', 'type of surface', 'GSR 751']
# ['requirements - No-', 'Height and slope of various types of', 'GSR 751']
# ['62.', 'instrument runways', 'surface', 'GSR 751']
# ['63', 'New objects or extension of existing', 'GSR 751']
# ['objects', 'GSR 751']
# ['Obstacle limitation', 'Obstacle limitations depending on the', 'GSR 751']
# ['64.', 'requirements-no', 'type of surface', 'GSR 751']
# ['65', 'precision approach', 'Height and slope of surfaces - A', 'GSR 751']
# ['66.', 'runway', 'Height and slope of surfaces - B', 'GSR 751']
# ['67.', 'New objects or extension of existing', 'GSR 751']
# ['68.', 'Obstacle limitation', 'Types of surfaces. CAT I', 'GSR 751']
# ['69.', 'requirements', 'Types of surfaces. CAT II and III', 'GSR 751']
# ['70.', 'precision approach', 'Height & slope of surfaces - A', 'GSR 751']
# ['71.', 'runway', 'Height & slopes of surfaces - B', 'GSR 751']
# ['72.', 'Fixed objects above surfaces', 'GSR 751']
# ['New objects or extension of existing', 'GSR 751']
# ['73.', 'objects', 'GSR 751']
# ['74.', 'Runways meant for', 'Type of obstacle limitation surface', 'GSR 751']
# ['75.', 'take-off', 'Dimensions of surfaces', 'GSR 751']
# ['New objects or extension of existing', 'GSR 751']
# ['76.', 'objects']
# ['77.', '5.1 -Indicators and']
# ['78.', 'Wind direction', 'Availability', '5.1.1.1']
# ['79.', 'indicator', 'Location', '5.1.1.2']
# ['80.', 'Landing direction', 'Availability', '5.1.2.1']
# ['81.', 'indicator', 'Location', '5.1.2.3']
# ['82.', 'Signalling lamp', 'Application', '5.1.3.1']
# ['Signal panels &', 'Characteristics of signal area', '5.1.4.2']
# ['83.', 'signal area']
# ['84.', '5.2 Markings']
# ['85.', 'Generals', 'General', 'interruption of runway', '5.2.1.1']
# ['86.', 'Interruption intersection rwy and twy', '5.2.1.3']
# ['87.', 'Color and conspicuity', 'RWY marking - White', '5.2.1.4']
# ['88.', 'TWY and other marking Yellow', '5.2.1.5']
# ['89.', 'Apron safety lines conspicuous', '5.2.1.6']
# ['90.', 'Runway designation', 'Marking at threshold', '5.2.2.1']
# ['91.', 'marking', 'Location of marking', '5.2.2.3']
# ['92.', 'Characteristics', '5.2.2.4']
# ['93.', 'Marking parallel runways', '5.2.2.5']
# ['94.', 'Proportions numbers and letters', '5.2.2.6']
# ['95.', 'Runway center line', 'Application', '5.2.3.1']
# ['96.', 'marking', 'Location', '5.2.3.2']
# ['97.', 'Characteristics', '5.2.3.3']
# ['98', 'Width of stripes', '5.2.3.4']
# ['100.', 'Location', '5.2.4.4']
# ['101.', 'Characteristics', '5.2.4.5']
# ['102.', 'Surface to be covered', '5.2.4.6']
# ['103.', 'Transverse stripe', 'Stripe width', '5.2.4.8']
# ['104.', 'Arrows', 'Permanently displaced threshold', '5.2.4.9']
# ['105.', 'Temporarily displaced threshold', '5.2.4.10']
# ['106.', 'Aiming point marking', 'Application', '5.2.5.1']
# ['107.', 'Use according with runway code', '5.2.5.2']
# ['108.', 'Location', '5.2.5.4']
# ['109.', 'Characteristics', '5.2.5.5']
# ['110.', 'Touchdown zone', 'Application', '5.2.6.1']
# ['111.', 'marking', 'Location and Characteristics', '5.2.6.3']
# ['112.', 'Configuration A et B', '5.2.6.4']
# ['113.', 'Runway side stripe', 'Application', '5.2.7.1']
# ['114.', 'Taxiway centre line', 'Application', '5.2.8.1']
# ['115.', 'marking', 'Standard taxi-route marking', '5.2.8.3']
# ['116.', 'Enhanced taxiway centre line marking', '5.2.8.5']
# ['117.', 'Location', 'enhanced marking', '5.2.8.9']
# ['118.', 'Characteristics - enhanced marking', '5.2.8.10']
# ['119.', 'Characteristics - figure 5-7', '5.2.8.11']
# ['120.', 'Runway turn pad', 'Application', '5.2.9.1']
# ['121.', 'marking', 'Characteristics', '5.2.9.7']
# ['122.', 'Runway-holding', 'Application and Location', '5.2.10.1']
# ['123.', 'position marking', 'Characteristics', '5.2.10.2']
# ['124.', 'Holding point Cat I', 'II and III', '5.2.10.3']
# ['125.', 'Runway-holding position', 'pattern A', '5.2.10.4']
# ['126.', 'Runway-holding position', 'runway', '5.2.10.7']
# ['intersection', 'pattern A']
# ['127.', 'Intermediate holding', 'Intersection - 2 taxiways', '5.2.11.3']
# ['128.', 'position marking', 'Distance between holding position', '5.2.11.4']
# ['129.', 'Characteristics', '5.2.11.5']
# ['130.', 'VOR Airport', 'Application', '5.2.12.1']
# ['131.', 'checkpoint marking', 'Site Selection', '5.2.12.2']
# ['132.', 'Location', '5.2.12.3']
# ['133.', 'Characteristics', '5.2.12.4']
# ['134.', 'Aircraft stand mark', 'No standard']
# ['135.', 'Apron safety line', 'Location', '5.2.14.2']
# ['136.', 'Road-holding position', 'Application', '5.2.15.1']
# ['137.', 'marking', 'Location', '5.2.15.2']
# ['138.', 'Characteristics local traffic regulation', '5.2.15.3']
# ['139.', 'Mandatory instruction', 'Application', '5.2.16.1']
# ['140.', 'marking', 'Location', 'code letter A', 'B', 'C and D', '5.2.16.3']
# ['141.', 'Location', 'code letter E and F', '5.2.16.4']
# ['142.', 'Characteristics - No entry.', '5.2.16.6']
# ['143.', 'Characteristics - No entry', 'colors', '5.2.16.7']
# ['144.', 'Characteristics - Conspicuity', '5.2.16.8']
# ['145.', 'Information marking', 'Application', '5.2.17.1']
# ['146.', 'Characteristics', '5.2.17.6']
# ['147.', 'Conspicuity', '5.2.17.7']
# ['148.', '5.3 Lights']
# ['General', 'Lights which may endanger safety of', '5.3.1.1']
# ['149.', 'aircraft']
# ['150.', 'Elevated approach', 'Frangibility', '5.3.1.4']
# ['151.', 'lights', '5.3.1.4 applicable after January 1', '5.3.1.5']
# ['152.', 'Marking for conspicuity', '5.3.1.6']
# ['153.', 'Elevated lights', 'Frangibility and clearance for', '5.3.1.7']
# ['154.', 'Surface lights', 'Design', '5.3.1.8']
# ['155.', 'Light intensity and', 'Intensity for visibility', '5.3.1.10']
# ['156.', 'control', 'Intensity control', '5.3.1.11']
# ['157.', 'Intensity maximum A', '5.3.1.12']
# ['158.', 'Intensity maximum B', '5.3.1.13']
# ['Aeronautical beacons', 'If operationally required', '5.3.3.1']
# ['Requirements for establishing', '5.3.3.2']
# ['Airport beacons', 'Conditions to have a beacon', '5.3.3.3']
# ['Location', '5.3.3.4']
# ['Characteristics', '5.3.3.6']
# ['Visibility angles', '5.3.3.7']
# ['dentification beacon', 'Application', '5.3.3.8']
# ['Location', '5.3.3.9']
# ['Characteristics', '5.3.3.11']
# ['Colour of flashing lights', '5.3.3.12']
# ['Identification', 'Morse code', '5.3.3.13']
# ['Approach lighting', 'Application', 'non-instrument RWY', '5.3.4.1']
# ['system', 'Application non-precision approach', '5.3.4.1']
# ['Application', 'Precision approach', '5.3.4.1']
# ['Application', 'Precision approach', '5.3.4.1']
# ['Simple approach', 'Location', '5.3.4.2']
# ['lighting system', 'Position of lights on crossbar', '5.3.4.3']
# ['Centre line lights', '5.3.4.4']
# ['Position of the system - plane to thld', '5.3.4.6']
# ['Characteristics', '5.3.4.7']
# ['Precision approach', 'Location', '5.3.4.10']
# ['CAT I lighting system', 'Position - runway centre line', '5.3.4.11']
# ['Centre line - space between lights', '5.3.4.12']
# ['Position of the system - horizontal', '5.3.4.13']
# ['Characteristics - fixed lights showing', '5.3.4.14']
# ['Serviceability level', '5.3.4.15']
# ['Barrettes - light spacing', '5.3.4.16']
# ['Number of flashes per second.', '5.3.4.18']
# ['Additional lights on crossbar.', '5.3.4.19']
# ['Position of additional lights', '5.3.4.20']
# ['Lights conform to Appendix 2', 'Figure', '5.3.4.21']
# ['Precision approach', 'Location distance in the extended', '5.3.4.22']
# ['CAT II and III lighting', 'center line']
# ['system', 'Location longitudinal intervals', '5.3.4.23']
# ['Location - on barrettes', '5.3.4.24']
# ['Crossbar at 150 meters', '5.3.4.25']
# ['Crossbar at 300 meters', '5.3.4.26']
# ['Additional crossbars', '5.3.4.27']
# ['Position of lights on additional', '5.3.4.28']
# ['Position horizontal plan', '5.3.4.29']
# ['Characteristics - for the first 300 m.', '5.3.4.30']
# ['Characteristics - over 300 meters', '5.3.4.31']
# ['Characteristics - Others', '5.3.4.32']
# ['Characteristics - Length of barrettes', '5.3.4.33']
# ['Characteristics - Flash per second', '5.3.4.35']
# ['Characteristics - Side row', 'color red', '5.3.4.36']
# ['Characteristics - Fixed lights', 'variable', '5.3.4.37']
# ['Characteristics - Compatibility', '5.3.4.38']
# ['Characteristics - Lights as per App 2', '5.3.4.39']
# ['Visual Approach', 'Application - Conditions for', '5.3.5.1']
# ['Slope Indicator', 'establishment']
# ['System', 'Application -']
# ['Application - Criteria for installation', '5.3.5.3']
# ['Application - Criteria for installation', '5.3.5.4']
# ['T-VASIS & AT-VASIS', 'description', '5.3.5.6']
# ['T-VASIS & AT-VASIS', 'description', '5.3.5.7']
# ['T-VASIS & AT-VASIS', 'description', '5.3.5.8']
# ['T-VASIS & AT-VASIS - Location', '5.3.5.9']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.10']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.11']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.12']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.13']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.14']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.15']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.16']
# ['T-VASIS & AT-VASIS - caract. of the', '5.3.5.17']
# ['Approach slope and', 'Approach slope appropriate for', '5.3.5.18']
# ['elevation settings of', 'aircraft using the approach']
# ['light beams', 'Visual approach slope conform', '5.3.5.19']
# ['Same setting', 'both end of runway', '5.3.5.20']
# ['Slope to clear all objects', '5.3.5.21']
# ['Adjustment of azimuth', '5.3.5.22']
# ['PAPI et APAPI', 'Description: PAPI', '5.3.5.23']
# ['Description: APAPI', '5.3.5.24']
# ['Description: PAPI position of red and', '5.3.5.25']
# ['Description: APAPI position of red', '5.3.5.26']
# ['Location: figure 5-18', '5.3.5.27']
# ['Characteristics: day and night', '5.3.5.28']
# ['Characteristics: others', '5.3.5.29']
# ['Characteristics: others', '5.3.5.30']
# ['Distribution light intensity', 'App. 2', '5.3.5.31']
# ['Intensity control', '5.3.5.32']
# ['Adjustment in elevation - limits', '5.3.5.33']
# ['Design to avoid accumulation of FOD', '5.3.5.34']
# ['Approach slope', 'figure 5-19', '5.3.5.35']
# ['Compatibility with ILS slope', '5.3.5.36']
# ['Slope angle to clear all objects.', '5.3.5.37']
# ['Same for APAP', '5.3.5.38']
# ['Azimuth spread of the light beam', '5.3.5.39']
# ['Same setting at both end of rwy', '5.3.5.40']
# ['Establishment of an obstacle', '5.3.5.41']
# ['Characteristic of the protection', '5.3.5.42']
# ['surface', 'Tableau 5-3 et fig. 5-20']
# ['New objects or extension of existing', '5.3.5.43']
# ['Removal of objects above obstacle', '5.3.5.44']
# ['Mitigation measures', '5.3.5.45']
# ['RWY lead-in lighting', 'No standard']
# ['RWY threshold', 'Location', '5.3.8.2']
# ['identification lights', 'Visible in the approach direction', '5.3.8.4']
# ['Runway edge lights', 'Application criteria', 'night operation or', '5.3.9.1']
# ['Location', '2 parallel row equidistant', '5.3.9.3']
# ['Location less than 3 metres from the', '5.3.9.4']
# ['Distance between lights', '60 or 100', '5.3.9.6']
# ['Characteristics: fix', 'white', 'variable', '5.3.9.7']
# ['Characteristics visible all angles', '5.3.9.8']
# ['Characteristics: 15 degrees above', '5.3.9.9']
# ['Characteristics: precision approach', '5.3.9.10']
# ['App 2', 'fig A2-9 and A2-10']
# ['Runway threshold', 'Application - RWY THLD Lights', '5.3.10.1']
# ['and wing bar lights', 'Location of lights at rwy end', '5.3.10.2']
# ['Location THLD lights', 'displaced thld', '5.3.10.3']
# ['Threshold: number of lights', '5.3.10.4']
# ['Wing bar thld lights', 'displaced thld', '5.3.10.7']
# ['Location of wing bar lights', '5.3.10.8']
# ['Characteristics: green', '5.3.10.9']
# ['Thld light', 'precision approach App. 2', '5.3.10.10']
# ['Thld wing bar light with precision', '5.3.10.11']
# ['Approach App 2', 'Fig. A2-4']
# ['Runway end lights', 'Mandatory for rwy equipped with edge', '5.3.11.1']
# ['Location', '5.3.11.2']
# ['275.', 'Characteristics: fix', 'unidirectional.', 'red', '5.3.11.4']
# ['Rwy end with precision approach', '5.3.11.5']
# ['276.', 'App 2', 'Fig A2-8']
# ['Runway Center Line', 'Mandatory for precision approach', '5.3.12.1']
# ['277.', 'Lights', 'CAT II and III']
# ['Mandatory for T/Off with RVR less', '5.3.12.3']
# ['278.', 'than 400 m.']
# ['279.', 'Location of lights', '5.3.12.5']
# ['Characteristics: fix', 'white', 'variable', '5.3.12.7']
# ['280.', 'intensity', 'etc.']
# ['Characteristics: accordance with', '5.3.12.8']
# ['281.', 'App. 2', 'Fig. A2-6 and A2-7']
# ['282.', 'Runway touchdown', 'Mandatory for precision approach Cat', '5.3.13.1']
# ['zone lights', 'II et III']
# ['283.', 'Location', '5.3.13.2']
# ['Characteristics: number of lights per', '5.3.13.3']
# ['284.', 'barrette and spacing']
# ['285.', 'Characteristics: fix', 'unidirectional', '5.3.13.5']
# ['white', 'variable']
# ['Accordance with spec. App 2', 'Fig. A2-', '5.3.13.6']
# ['286.', '5']
# ['287.', 'Rapid exit taxiway', 'Not to be on if pattern is not as fig 5-', '5.3.14.2']
# ['indicator lights', '24', 'in full.']
# ['288.', 'Located same side of the CL as the', '5.3.14.3']
# ['TWY', 'configur. Fig 5-23']
# ['289.', 'No overlapping when displayed', '5.3.14.4']
# ['Light yellow', 'unidirectional fix', '5.3.14.5']
# ['290.', 'visible direction approach.']
# ["Conform spec. 'App. 2", 'Fig. A2-6 or', '5.3.14.6']
# ['291.', 'A2-7']
# ['292.', 'if used at', '5.3.15.1']
# ['Location', '5.3.15.2']
# ['Characteristics', '5.3.15.3']
# ['Taxiway centre line', 'Mandatory is use with RVR less than', '5.3.16.1']
# ['lights', '350 m.']
# ['TWY lights on RWY if used as a', '5.3.16.4']
# ['Characteristics: green with reduced', '5.3.16.6']
# ['TWY lights on RWY exit shall be', '5.3.16.7']
# ['alternatively green & yellow', 'etc.']
# ['Conform Appendix 2', 'various figures', '5.3.16.8']
# ['Taxiway edge lights', 'Installed on rwy turn pas', 'holding bay', '5.3.17.1']
# ['and apron', 'etc. if used at night']
# ['Installed on rwy is part of taxi-route.', '5.3.17.2']
# ['Characteristics: blue', 'fix', 'visible 30', '5.3.17.7']
# ['Runway turn pad', 'Application', '5.3.18.1']
# ['lights', 'Light fix', 'unidirectional', 'green', '5.3.18.6']
# ['Conform spec. Appendices 2', 'Fig. A2-', '5.3.18.7']
# ['13', '14 ou 15']
# ['Stop bars', 'Mandatory if rwy use RVR les than', '5.3.19.1']
# ['350 m', 'etc.']
# ['Mandatory if rwy use with RVR', '5.3.19.2']
# ['Location', '5.3.19.5']
# ['Characteristics: Light red', 'spacing 3', '5.3.19.6']
# ['Characteristics: Rwy-holding position', '5.3.19.7']
# ['unidirectional', 'red', 'visible when']
# ['Additional lights as spec. 5.3.19.4', '5.3.19.8']
# ['switchable bars', '5.3.19.9']
# ['313.', 'App. 2', 'Fig.: Q2-12 to to16']
# ['314.', 'Electrical circuit: design', '5.3.19.13']
# ['315.', 'Intermediate holding', 'Conditions for installation', '5.3.20.1']
# ['316.', 'position lights', 'Location', '5.3.20.3']
# ['317.', 'Characteristics', '5.3.20.4']
# ['318.', 'De-icing/anti-icing', 'Location', '5.3.21.2']
# ['319.', 'facility exit lights', 'Characteristics', '5.3.21.3']
# ['320.', 'Runway Guard Lights', 'Application', '5.3.22.1']
# ['321.', 'Location configuration A', '5.3.22.4']
# ['322.', 'Location configuration B', '5.3.22.5']
# ['323.', 'Characteristics configuration A', '5.3.22.6']
# ['324.', 'Characteristics configuration B', '5.3.22.8']
# ['325.', 'Light beam definition', '5.3.22.9']
# ['326.', 'Lighting sequence light', 'confi. A', '5.3.22.16']
# ['327.', 'Lighting sequence light Config. B', '5.3.22.17']
# ['328.', 'Cycle 30 a 60 cycles per minute', '5.3.22.18']
# ['Apron floodlighting', 'Spectral distribution of apron', '5.3.23.3']
# ['329.', 'floodlight']
# ['330.', 'Visual docking', 'Application', '5.3.24.1']
# ['331.', 'guidance system', 'Application after 01 January 2005', '5.3.24.2']
# ['332.', 'Characteristics', '5.3.24.3']
# ['333.', 'Functioning under all conditions', '5.3.24.4']
# ['334.', 'Indication for malfunctioning', '5.3.24.5']
# ['335.', 'Location of the system', '5.3.24.6']
# ['336.', 'Accuracy adapted to each bridge', '5.3.24.7']
# ['337.', 'Identification of the selected aircraft', '5.3.24.9']
# ['338.', 'Azimuth guidance unit location', '5.3.24.10']
# ['339.', 'Guidance information', '5.3.24.12']
# ['340.', 'Guidance color', 'green and red', '5.3.24.13']
# ['341.', 'Stopping position', 'Location', '5.3.24.14']
# ['342.', 'indicator', 'Visible from the left seat', '5.3.24.15']
# ['Indication closing speed', '5.3.24.18']
# ['Green to go ahead', 'red to stop', '5.3.24.20']
# ['Advanced visual', 'Color red', 'fix', 'unidirectional', '5.3.25.5']
# ['docking guidance', 'Guidance information', '5.3.25.6']
# ['system', 'Info available for all aft taxi speed', '5.3.25.7']
# ['Time of display not to allow', '5.3.25.8']
# ['Symbols & graphics to be intuitive', '5.3.25.10']
# ['Time for communicating lateral', '5.3.25.11']
# ['Closure distance and closure rate', '15', '5.3.25.12']
# ['Emergency stop device', '5.3.25.14']
# ['Emergency stop for operating staff', '5.3.25.15']
# ['Aircraft stand', 'Location', '5.3.26.2']
# ['manoeuvring', 'Characteristics: colors', '5.3.26.3']
# ['guidance lights', 'Stop position : fix', 'unidirectional', 'red', '5.3.26.5']
# ['Road-holding position', 'Mandatory if RVR less than 350 m', '5.3.27.1']
# ['light', 'Location', '5.3.27.3']
# ['Characteristic composition', '5.3.27.4']
# ['Unidirectional', 'visible when approach', '5.3.27.5']
# ['Intensity of the light beam', '5.3.27.6']
# ['Flash frequency', 'between 30 & 60 per', '5.3.27.7']
# ['5.4 Signs', 'Application : mandatory instructions', '5.4.1.1']
# ['Characteristics Frangible', 'low', '5.4.1.3']
# ['dimension & height', 'Tableau 5-5']
# ['Rectangular signs', 'Fig. 5-29& 5-30', '5.4.1.4']
# ['Red for mandatory instruction sign', '5.4.1.5']
# ['368.', 'Inscription Appendix', '5.4.1.6']
# ['369.', 'Illuminated signs', 'see conditions', '5.4.1.7']
# ['370.', 'Retro reflective code 1 et 2', 'non-', '5.4.1.8']
# ['Panel variable message', 'white when', '5.4.1.9']
# ['371.', 'not used']
# ['372.', 'Panel variable message', 'no', '5.4.1.10']
# ['373.', 'Mandatory instruction', 'Authorization to go ahead', '5.4.2.1']
# ['374.', 'sign', 'Content of mandatory instruction sign', '5.4.2.2']
# ['Intersection rwy/twy & rwy/rwy. Pattern', '5.4.2.3']
# ['375.', 'A']
# ['376.', 'Rwy holding position for Cat I', 'II or III.', '5.4.2.4']
# ['377.', 'Sign to be installed with marking', '5.4.2.5']
# ['378.', 'No Entry sign', '5.4.2.7']
# ['379.', 'Location', '5.4.2.8']
# ['380.', 'Location - other', '5.4.2.9']
# ['381.', 'Location - other', '5.4.2.10']
# ['382.', 'Location - other', '5.4.2.11']
# ['Characteristics: mandatory = white on', '5.4.2.12']
# ['383.', 'red background']
# ['384.', 'Characteristics. : runway designation', '5.4.2.14']
# ['385.', 'Characteristics: designation Cat I', 'II', '5.4.2.15']
# ['386.', 'Characteristics: No Entry sign', 'Fig. 5-', '5.4.2.16']
# ['Characteristics." \'rwy holding sign', 'tu', '5.4.2.17']
# ['387.', 'design and a number"']
# ['388.', 'Characteristics: symbols', '5.4.2.18']
# ['389.', 'Information signs', 'Application', '5.4.3.1']
# ['390.', 'Information signs to include', '5.4.3.2']
# ['Runway vacated sign', '5.4.3.4']
# ['Sign at intersection TWY', '5.4.3.7']
# ['Direction sign intersection twy/twy', '5.4.3.8']
# ['Location sign with rwy designation', '5.4.3.10']
# ['Location sign with direction sign', '5.4.3.11']
# ['Location : left side of Twy', 'see except.', '5.4.3.14']
# ['Location: information sign', '5.4.3.15']
# ['Location: Rwy exit sign same side as', '5.4.3.16']
# ['Location : Rwy exit sign', '60 m before', '5.4.3.17']
# ['Location: Rwy vacated sign', '5.4.3.18']
# ['Location: combined sign', 'vacated rwy', '5.4.3.19']
# ['Location: intersection take-off sign', '5.4.3.20']
# ['Positioning : Sign twy location with', '5.4.3.21']
# ['Information sign colourcoted with', '5.4.3.23']
# ['Characteristics (C): information sign', '5.4.3.25']
# ['Location sign= yellow on black', '5.4.3.26']
# ['C: Rwy exit = twy designator + arrow', '5.4.3.27']
# ['C Content rwy vacated sign', 'fig. 5-', '5.4.3.28']
# ['29', 'A']
# ['C: Take-off sign', '5.4.3.29']
# ['C: Inscription on destination sign', '5.4.3.30']
# ['C: Inscription on direction pane', '5.4.3.31']
# ['413.', 'C: Inscription on location sign', '5.4.3.32']
# ['C: Location & direction panels co-', '5.4.3.34']
# ['414.', 'located']
# ['C: Identification of twy: letter with', '5.4.3.35']
# ['415.', 'number']
# ['C: Number only on manoeuvring area', '5.4.3.37']
# ['416.', '= for rwy designation']
# ['417.', 'VOR Aerodrome', 'If VOR checkpoint is established', 'it', '5.4.4.1']
# ['Checkpoint Sign', 'must be indicated with marking']
# ['418.', 'Location', '5.4.4.2']
# ['419.', 'Colour', '5.4.4.3']
# ['Airport Identification', 'Name of the aerodrome', '5.4.5.3']
# ['420.', 'sign']
# ['421.', 'Road-holding position', 'Installed everywhere road lead to rwy', '5.4.7.1']
# ['422.', 'sign', 'Location', '5.4.7.2']
# ['423.', 'White on red background', '5.4.7.3']
# ['424.', 'National language', '5.4.7.4']
# ['425.', 'llluminated if use at night', '5.4.7.5']
# ['426.', '5.5 Markers', 'Frangible and low', '5.5.1']
# ['427. 428.', 'Stop way edge marker different from rwy edge marker', '5.5.3.2']
# ['429. 430.', 'Twy edge marker E retro reflective blue', '5.5.5.3']
# ['431.', 'Twy edge marker = frangible & low', '5.5.5.5']
# ['432. 433.', 'Twy centre line marker = retro reflective green', '5.5.6.5']
# ['434. 435.', 'Twy centre line marker', 'designed to support aircraft weight', '5.5.6.7']
# ['436. 437.', 'Boundary markers used when there is no rwy', '5.5.8.1']
# ['438.', 'Location', '5.5.8.2']
# ['439.', '6.1 Objects to be', 'Fixe object +3000 m', 'approach or', '6.1.3']
# ['and/or', 'transitional surface shall be marked or']
# ['Fixe object above obstacle protection', '6.1.5']
# ['Marks for vehicles', '6.1.6']
# ['Mark for elevated aeronautical ground', '6.1.7']
# ['Obstacles', 'Ref. distance table 3-1', '6.1.8']
# ['of', 'Fixe objects to be colored or marked', '6.2.1']
# ['Mobile objects colored or flags', '6.2.2']
# ['Use of markers', '6.2.7']
# ['Use of flags', '6.2.11']
# ['Design of flags for fix objects', '6.2.12']
# ['Design of flags for mobile objects', '6.2.14']
# ['of', 'Low', 'medium or high intensity', '6.3.1']
# ['Obstacle light for vehicles & mobile', '6.3.4']
# ['Obstacle light for <<FOLLOW ME >)', '6.3.5']
# ['Obstacle light at top of obstacle', '6.3.11']
# ['Special cases', 'pylons etc.', '6.3.13']
# ['Special cases', 'extensive or closely', '6.3.14']
# ['Special cases', '+ 105 metres above', '6.3.16']
# ['Idem', 'more than 45 metres', '6.3.17']
# ['Idem', '6.3.18']
# ['Special cases : to see', '6.3.19']
# ['Special case', 'height', 'type of lights', '6.3.20']
# ['Light on fix object = fix red light', '6.3.23']
# ['462.', 'tableau']
# ['463.', 'Obstacle light low intens', 'type A & B', '6.3.24']
# ['Obstacle light on emergency vehicle =', '6.3.25']
# ['464.', 'flashing blue']
# ['Obstacle light on FOLLOW ME E', '6.3.26']
# ['465.', 'flashing yellow']
# ['466.', 'Obstacle light low intens', 'type C and', '6.3.27']
# ['467.', 'Obstacles light on bridge E fix red', '6.3.28']
# ['Obstacle light on object with limited', '6.3.29']
# ['468.', 'mobility conform type A', 'table 6-3']
# ['Obstacle light', 'definition type A et B', '6.3.30']
# ['469.', 'et C: couleurs']
# ['470.', 'Obstacle light types A', 'B', 'C table 6-3', '6.3.31']
# ['471.', 'Obstacle light', 'medium intens', 'type A', '6.3.32']
# ['472.', 'HI Obstacle light types A & B =', '6.3.33']
# ['473.', 'Obstacle light HI', 'types A & B', '6.3.34']
# ['474.', 'Obstacle light HI', 'type A on object =', '6.3.35']
# ['6.4 Wind Turbines', 'Wind turbines shall be marked and/or', '6.4.1']
# ['475.', 'lighted if it constitutes an obstacle']
# ['476.', '7.1 Closed runways', 'Application', '7.1.1']
# {'ITEMS': ',STANDARDS,REF ANN. 14,C,N C,N/A,COMMENTS', '3.1 Runways': ',RWY surfaces WIO irregularities,3.1.22', 'RWY': ',friction characteristics on wet,3.1.23', '3.2 Runway': ',No standard', '3.3 Runway Turn': ',Application for code D,E or F,3.3.1', 'Pads': ',Runway turn pad - design,3.3.6', 'Surface of RWY turn pads': ',3.3.10', '3.4 Runway Strips': ',General - RWY and stop way included in,3.4.1', 'Length of rwy strip': ',3.4.2', 'Width of rwy strip': ',3.4.3', 'Objects on rwy strip': ',3.4.7', 'Junction rwy and other surfaces': ',3.4.10', '3.5 Runway End': ',General - mandatory depending on runway,3.5.1', 'Safety Area (RESA)': ',code', 'Dimensions': ',length,3.5.2', 'Dimensions width': ',3.5.4', '3.6 Clearways': ',No standard', '3.7 Stop ways': ',Width,3.7.1', '3.8 Radio Altimeter': ',No standard', '20.': ',3.9 Taxiways,Clearances,design,3.9.4', '21.': ',Taxiways on bridge,3.9.20', '22.': ',3.10 Taxiway,No standard', '23.': ',3.11 TWY strips,Twy included in a strip,3.11.1', '24.': ',3.12 Holding bays,Establishment criteria rwy-holding position,3.12.2', 'rwy-holding': ',Establishment criteria rwy-holding position,3.12.3', '25.': ',positions,to protect navaids', '26.': ',intermediate holding,Road-holding position - rwy,3.12.5', '27.': ',positions,road-,Location of above signs,3.12.6', '28.': ',holding positions,RWY holding position & ILS protection,3.12.9', '29.': ',3.13 Apron,No standard', '30.': ',3.14 Isolated aircraft,Identification of an isolated aircraft parking,3.14.1', 'parking position': ',position', '31.': ',3.15 De-icing,No standard', '32': ',4.1 Obstacle,Conical surface,description,GSR 751', '33.': ',Limitation Surfaces,Conical surface,characteristics,GSR 751', '34.': ',Conical surface,slopes,GSR 751', '35.': ',Inner horizonta,Description,GSR 751', '36.': ',surface,Characteristics,GSR 751', '37.': ',Height,method of measurement,GSR 751', '38.': ',Approach surface,Description,GSR 751', '39.': ',Characteristics,GSR 751', '40.': ',Elevation of inner edge,GSR 751', '41.': ',Slope of approach surface,GSR 751', '42.': ',Inner approach,Description,GSR 751', '44.': ',Transitional surface,Description,GSR 751', '45.': ',Characteristics,GSR 751', '46.': ',Elevation,GSR 751', '47.': ',Slopes,GSR 751', '48.': ',Inner transitional,Description,GSR 751', '49.': ',surface,Characteristics,GSR 751', '50.': ',Elevation,GSR 751', '51.': ',Slopes,GSR 751', '52.': ',Balked landing,Description,GSR 751', '53.': ',surface,Characteristics,GSR 751', '54.': ',Elevation,GSR 751', '55.': ',Slopes,GSR 751', '56.': ',Take-off climb,Description,GSR 751', '57.': ',surface,Characteristics,GSR 751', '58.': ',Elevationof inner edge,GSR 751', '59.': ',Take-off flight path,Measurement -A,GSR 751', '60.': ',Measurement - - B,GSR 751', '61.': ',4.2 Obstacle,Obstacle limitations depending on the,GSR 751', 'limitation': ',type of surface,GSR 751', 'requirements - No-': ',Height and slope of various types of,GSR 751', '62.': ',instrument runways,surface,GSR 751', '63': ',New objects or extension of existing,GSR 751', 'objects': ',GSR 751', 'Obstacle limitation': ',Obstacle limitations depending on the,GSR 751', '64.': ',requirements-no,type of surface,GSR 751', '65': ',precision approach,Height and slope of surfaces - A,GSR 751', '66.': ',runway,Height and slope of surfaces - B,GSR 751', '67.': ',New objects or extension of existing,GSR 751', '68.': ',Obstacle limitation,Types of surfaces. CAT I,GSR 751', '69.': ',requirements,Types of surfaces. CAT II and III,GSR 751', '70.': ',precision approach,Height & slope of surfaces - A,GSR 751', '71.': ',runway,Height & slopes of surfaces - B,GSR 751', '72.': ',Fixed objects above surfaces,GSR 751', 'New objects or extension of existing': ',5.3.5.43', '73.': ',objects,GSR 751', '74.': ',Runways meant for,Type of obstacle limitation surface,GSR 751', '75.': ',take-off,Dimensions of surfaces,GSR 751', '76.': ',objects', '77.': ',5.1 -Indicators and', '78.': ',Wind direction,Availability,5.1.1.1', '79.': ',indicator,L ...

# %%
master_dict={}
for i in range(len(dup)):
    
    master_dict[dup[i][0]] = dup[i][1]
print(master_dict)
# Out:
# {'ITEMS': 'STANDARDS', '3.1 Runways': 'RWY surfaces WIO irregularities', 'RWY': 'friction characteristics on wet', '3.2 Runway': 'No standard', '3.3 Runway Turn': 'Application for code D', 'Pads': 'Runway turn pad - design', 'Surface of RWY turn pads': '3.3.10', '3.4 Runway Strips': 'General - RWY and stop way included in', 'Length of rwy strip': '3.4.2', 'Width of rwy strip': '3.4.3', 'Objects on rwy strip': '3.4.7', 'Junction rwy and other surfaces': '3.4.10', '3.5 Runway End': 'General - mandatory depending on runway', 'Safety Area (RESA)': 'code', 'Dimensions': 'length', 'Dimensions width': '3.5.4', '3.6 Clearways': 'No standard', '3.7 Stop ways': 'Width', '3.8 Radio Altimeter': 'No standard', '20.': '3.9 Taxiways', '21.': 'Taxiways on bridge', '22.': '3.10 Taxiway', '23.': '3.11 TWY strips', '24.': '3.12 Holding bays', 'rwy-holding': 'Establishment criteria rwy-holding position', '25.': 'positions', '26.': 'intermediate holding', '27.': 'positions', '28.': 'holding positions', '29.': '3.13 Apron', '30.': '3.14 Isolated aircraft', 'parking position': 'position', '31.': '3.15 De-icing', '32': '4.1 Obstacle', '33.': 'Limitation Surfaces', '34.': 'Conical surface', '35.': 'Inner horizonta', '36.': 'surface', '37.': 'Height', '38.': 'Approach surface', '39.': 'Characteristics', '40.': 'Elevation of inner edge', '41.': 'Slope of approach surface', '42.': 'Inner approach', '44.': 'Transitional surface', '45.': 'Characteristics', '46.': 'Elevation', '47.': 'Slopes', '48.': 'Inner transitional', '49.': 'surface', '50.': 'Elevation', '51.': 'Slopes', '52.': 'Balked landing', '53.': 'surface', '54.': 'Elevation', '55.': 'Slopes', '56.': 'Take-off climb', '57.': 'surface', '58.': 'Elevationof inner edge', '59.': 'Take-off flight path', '60.': 'Measurement - - B', '61.': '4.2 Obstacle', 'limitation': 'type of surface', 'requirements - No-': 'Height and slope of various types of', '62.': 'instrument runways', '63': 'New objects or extension of existing', 'objects': 'GSR 751', 'Obstacle limitation': 'Obstacle limitations depending on the', '64.': 'requirements-no', '65': 'precision approach', '66.': 'runway', '67.': 'New objects or extension of existing', '68.': 'Obstacle limitation', '69.': 'requirements', '70.': 'precision approach', '71.': 'runway', '72.': 'Fixed objects above surfaces', 'New objects or extension of existing': '5.3.5.43', '73.': 'objects', '74.': 'Runways meant for', '75.': 'take-off', '76.': 'objects', '77.': '5.1 -Indicators and', '78.': 'Wind direction', '79.': 'indicator', '80.': 'Landing direction', '81.': 'indicator', '82.': 'Signalling lamp', 'Signal panels &': 'Characteristics of signal area', '83.': 'signal area', '84.': '5.2 Markings', '85.': 'Generals', '86.': 'Interruption intersection rwy and twy', '87.': 'Color and conspicuity', '88.': 'TWY and other marking Yellow', '89.': 'Apron safety lines conspicuous', '90.': 'Runway designation', '91.': 'marking', '92.': 'Characteristics', '93.': 'Marking parallel runways', '94.': 'Proportions numbers and letters', '95.': 'Runway center line', '96.': 'marking', '97.': 'Characteristics', '98': 'Width of stripes', '100.': 'Location', '101.': 'Characteristics', '102.': 'Surface to be covered', '103.': 'Transverse stripe', '104.': 'Arrows', '105.': 'Temporarily displaced threshold', '106.': 'Aiming point marking', '107.': 'Use according with runway code', '108.': 'Location', '109.': 'Characteristics', '110.': 'Touchdown zone', '111.': 'marking', '112.': 'Configuration A et B', '113.': 'Runway side stripe', '114.': 'Taxiway centre line', '115.': 'marking', '116.': 'Enhanced taxiway centre line marking', '117.': 'Location', '118.': 'Characteristics - enhanced marking', '119.': 'Characteristics - figure 5-7', '120.': 'Runway turn pad', '121.': 'marking', '122.': 'Runway-holding', '123.': 'position marking', '124.': 'Holding point Cat I', '125.': 'Runway-holding position', '126.': 'Runway-holding position', 'intersection': 'pattern A', '127.': 'Intermediate holding', '128 ...

# %%
master_dict = {}
for i in master_list:
    #try:
        master_dict[i[0]] = i[1:] 
    #except:
    #    print("error")
    #    print(rows.index(i))
print(master_dict.keys())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-405676281f8e> in <module>
#       2 for i in master_list:
#       3     #try:
# ----> 4         master_dict[i[0]] = i[1:]
#       5     #except:
#       6     #    print("error")
#
# IndexError: list index out of range

# %%
import json
json_object = json.dumps(master_dict, indent = 4)   
print(json_object)
# Out:
# {
#     "Aerodrome and Site Clearance": "Form",
#     "Name of the applicant": "Sudhanshu Chaudhary",
#     "Full Address": "Anmol Ratan Building",
#     "Te No./Fax No.": "9876543210",
#     "Permanent E-Mail Address": "Sudhanshu@indianair.com",
#     "Name of the Directors/ Partners/Promoters": "None",
#     "Nature of the applicant firm or company": "Public Limited Company",
#     "Location of Aerodrame": "Greater Noida",
#     "Name of nearest civilian airport": "IGI",
#     "Nearest Civilain airport distance from proposed airport": "84.2 kms",
#     "Tota Land Area identified": "2200acres",
#     "Ownership of Land": "Governmnet",
#     "Forest land": "None",
#     "If the land is not in ownership or possession": "N/A",
#     "Likely displacement of population": "Yes",
#     "Status of Forest(Conservation) Act 1980": "N/A",
#     "Status of Clearance under EMP Notification": "N/A",
#     "Status of Clearance under CRZ Notification": "N/A",
#     "Status of Clearance under Wildlife Act 1972": "N/A",
#     "Category of aerodrome proposed": "Private",
#     "Whether project located within 150 Km of an existing civilian airport": "Yes",
#     "Whether exemption from any conditions is sought.": "None",
#     "Allowing a greenfield airport within 150 Km of an existing civilian airport.": "None",
#     "Exemptions being sought form conditionalities imposed by any of the Central Agencies": "Yes",
#     "Facilitation in obtaining approval/clearance from a Central Agency.": "None",
#     "Site of Aerodrome": "Jewar",
#     "District of Aerodrome": "Gautam Budh Nagar",
#     "State of Aerodrome": "Uttar Pradesh",
#     "Implementing Agency": "Flughafen Zurich AG",
#     "Whether TechnoEconomic Feasibility Report (TM) has been submitted by the Applicant": "Done",
#     "Estimated Total Projec Cost": "29560crore",
#     "Is any foreign participation envisaged. If yes from which countries": "Yes",
#     "Capacity of passenger proposed": "12million",
#     "Capacity of cargo proposed": "2300tons",
#     "Number of runways": "6",
#     "Length of runways": "6000ft",
#     "Number of taxiways": "15",
#     "Area of Passenger Terminal": "1",
#     "Area of Cargo Terminal": "1",
#     "Area earmarked for city side development.": "Jewar",
#     "Passenger related amenities on city side like car parking": "Parking Slot",
#     "Total Cost of Land": "20000 cr",
#     "Cost of other adjunct infrastrcure": "2000cr",
#     "Cost of Airside assets like Runways etc.": "1500cr",
#     "Cost of Passenger Terminal": "1000cr",
#     "Cost of Cargo Terminal and other airside aero facilities": "2500cr",
#     "Cost of Residential": "1000cr",
#     "Cost of Commerical-city side": "1000cr",
#     "Cost of other facilities": "1000cr",
#     "Equity Capital": "15000cr",
#     "Term Loan": "10000cr",
#     "External Commercial Borrowings": "None",
#     "Any other source": "None",
#     "Total Cost of Financing": "None",
#     "Foreign Direct Investment (FDI)": "None",
#     "Equity including Foreign Investment": "None",
#     "Pattern of share holding in the paidup capital": "N/A",
#     "Traffic projections made in the TEFR": "12 million passengers per annum",
#     "Revenue projections": "including details of fee etc. to be levied",
#     "IRR/NPV estimates based on TEFR": "N/A",
#     "Accessibility to site": "Road",
#     "Proposed projects to provide connectivity": "Metro by DMRC"
# }
