# %%
import pdf2image
from pdf2image import convert_from_path
pages = convert_from_path('AAI_doc.pdf', 500)

# %%
for page in pages:
    page.save('out.png', 'JPEG')    
    break

# %%
import webbrowser, os
import json
import boto3
import io
from io import BytesIO
import sys
from pprint import pprint

# %%
def get_rows_columns_map(table_result, blocks_map):
    rows = {}
    for relationship in table_result['Relationships']:
        if relationship['Type'] == 'CHILD':
            for child_id in relationship['Ids']:
                cell = blocks_map[child_id]
                if cell['BlockType'] == 'CELL':
                    row_index = cell['RowIndex']
                    col_index = cell['ColumnIndex']
                    if row_index not in rows:
                        # create new row
                        rows[row_index] = {}
                        
                    # get the text value
                    rows[row_index][col_index] = get_text(cell, blocks_map)
    return rows


def get_text(result, blocks_map):
    text = ''
    if 'Relationships' in result:
        for relationship in result['Relationships']:
            if relationship['Type'] == 'CHILD':
                for child_id in relationship['Ids']:
                    word = blocks_map[child_id]
                    if word['BlockType'] == 'WORD':
                        text += word['Text'] + ' '
                    if word['BlockType'] == 'SELECTION_ELEMENT':
                        if word['SelectionStatus'] =='SELECTED':
                            text +=  'X '    
    return text


def get_table_csv_results(file_name):

    with open(file_name, 'rb') as file:
        img_test = file.read()
        bytes_test = bytearray(img_test)
        print('Image loaded', file_name)

    # process using image bytes
    # get the results
    client = boto3.client('textract')

    response = client.analyze_document(Document={'Bytes': bytes_test}, FeatureTypes=['TABLES'])

    # Get the text blocks
    blocks=response['Blocks']
    pprint(blocks)

    blocks_map = {}
    table_blocks = []
    for block in blocks:
        blocks_map[block['Id']] = block
        if block['BlockType'] == "TABLE":
            table_blocks.append(block)

    if len(table_blocks) <= 0:
        return "<b> NO Table FOUND </b>"

    csv = ''
    for index, table in enumerate(table_blocks):
        csv += generate_table_csv(table, blocks_map, index +1)
        csv += '\n\n'

    return csv

def generate_table_csv(table_result, blocks_map, table_index):
    rows = get_rows_columns_map(table_result, blocks_map)

    table_id = 'Table_' + str(table_index)
    
    # get cells.
    csv = 'Table: {0}\n\n'.format(table_id)

    for row_index, cols in rows.items():
        
        for col_index, text in cols.items():
            csv += '{}'.format(text) + ","
        csv += '\n'
        
    csv += '\n\n\n'
    return csv

# %%
file_name = 'last_page.png'
table_csv = get_table_csv_results(file_name)
output_file = 'output.csv'


# replace content
with open(output_file, "w") as fout:
    fout.write(table_csv)

# show the results
print('CSV OUTPUT FILE: ', output_file)
# Out:
# Image loaded last_page.png
# [{'BlockType': 'PAGE',
#   'Geometry': {'BoundingBox': {'Height': 1.0,
#                                'Left': 0.0,
#                                'Top': 0.0,
#                                'Width': 1.0},
#                'Polygon': [{'X': 0.0, 'Y': 0.0},
#                            {'X': 1.0, 'Y': 0.0},
#                            {'X': 1.0, 'Y': 1.0},
#                            {'X': 0.0, 'Y': 1.0}]},
#   'Id': 'b7d7dd0c-9fdb-4f57-9b00-6a68f60d3759',
#   'Relationships': [{'Ids': ['913a712b-681c-497d-af42-d3d7fae9330b',
#                              '57148d7a-d082-4217-9fe1-ff323edde366',
#                              'a290a06e-3ad9-409b-b46c-e4399afb86d0',
#                              '95dfbf01-92a7-4e4a-896b-055edee97843',
#                              '38a4c4fb-56ba-4464-b05e-1fd95bc05bdf',
#                              '10cb6836-3714-4f82-869c-ae876cd9b7d3',
#                              '37ad900d-8129-41f9-a935-11b1b6c6b428',
#                              '56477e7a-eb2d-4151-bb7a-1177e82edc81',
#                              'e10584d7-d62a-48a6-a866-c6b33ca01da6',
#                              'ed8c778b-b431-480f-a383-eca9a933031e',
#                              '95adeeb4-422c-498f-a6cc-256ed00ffb3c',
#                              'd48150b1-138c-496c-a2d4-8b8c9f057a4d',
#                              'b11f38e6-4080-4dca-be38-d8c4c74eaf39',
#                              '6c7b6321-a8e0-4f09-80dd-9d6ce6106508',
#                              'e8bd4d35-82e8-42cf-9567-0b286ceeeb25',
#                              'f78be44a-f59d-4f3e-872a-84b2daffc93d',
#                              '9d6b1e5d-9d1e-4d9d-9c20-85731796e70b',
#                              'bf65abbc-7492-4ec2-a291-e9850c7d33d7',
#                              'f6b5d50e-f916-4ee8-b2cd-d5b773e3fd43',
#                              '96bf9064-3c6c-4253-bde2-8587e9918d54',
#                              'a5ee42e7-730f-4ef9-a75a-a08711ea5dc7',
#                              '9efe6adf-f9c3-42b5-80bb-10add3e02ff5',
#                              '508a50a5-2a08-4074-91d1-8dcdec2821bf',
#                              '37ff3324-be95-4e05-a9bd-baf17ef976de',
#                              '698a3890-7f00-405e-a78f-00e9d146ad5d',
#                              '2ecd9486-64bd-42c4-87c3-583b4dcce12d',
#                              '05674d1e-ef39-4b2d-ace0-eb9a9003b2bc',
#                              'a3dd4dd1-a905-44cb-894d-2037a195f15f',
#                              '40a014eb-5722-456b-9760-bc13e9784f31',
#                              'a60ddca6-bbee-4055-8714-559714a24813',
#                              '0cc9af7d-9573-4587-86e9-c188301b5aa2',
#                              '30845097-51e1-4d84-8044-7c6e72baf4e8',
#                              'eb5b15a8-d212-4dc0-8c60-4b11d1b970af',
#                              '17cf63d4-97f3-425f-996a-14c3eb4d8167',
#                              'a0e18886-4e83-4d83-bcd0-c0c75b3ae21b',
#                              '3cfb179d-9de4-4f3f-ad54-6846b9f9a1d9',
#                              'c302cc98-2ffa-49e6-a1ca-7d0bd853a510',
#                              '393bb39e-ecbb-49e8-bcf8-66c47bdafa3b',
#                              '9e373ad9-4281-4d86-b7bb-7e746156dba8',
#                              '2c7ed73b-6e03-4092-a182-acde81d6c815',
#                              'fba94e33-2496-4409-ae76-e6c511e2746f',
#                              'b13f7a6c-4593-4582-8b9a-13fe502a28ba',
#                              'c40ca0ec-66d8-47ea-92d3-7f9a81e8b542',
#                              '7bbd2633-9d76-403e-9805-135642c82505',
#                              '9476edf0-e25e-4acf-a661-6b2b1f8834d3',
#                              '98a9967f-7175-4d9b-b994-bcecf6e77b19',
#                              '32b3edf4-3edd-4bc2-8073-d2ee191da46d',
#                              '35a50e78-4938-42b8-9947-9582681acc8b',
#                              'd1e21164-fc5e-4822-86cf-2436fb89004a',
#                              '021dfdde-edf9-4d50-8f8a-c459a7af837d',
#                              '586e17e5-3c4d-486b-b2c6-459e2e86f3d9',
#                              '0ea36a87-a6fb-45ec-82c6-23ff9cf71ede'],
#                      'Type': 'CHILD'}]},
#  {'BlockType': 'LINE',
#   'Confidence': 97.85907745361328,
#   'Geometry': {'BoundingBox': {'Height': 0.01947573758661747,
#                                'Left': 0.17105020582675934,
#                                'Top': 0.02689204178750515,
#                                'Width': 0.6762074828147888},
#                'Polygon': [{'X': 0.17105020582675934, 'Y': 0.02689204178750515},
#                            {'X': 0.847257673740387, 'Y': 0.02689204178750515},
#                            {'X': 0.847257673740387, 'Y': 0.04636777937412262},
#                            {'X': 0.17105020582675934,
#                             'Y': 0.04636777937412262}]},
#   'Id': '913a712b-681c-497d-af42-d3d7fae9330b',
#   'Relationships': [{'Ids': ['83b44677-f516-49a1-93bd-778044a0d25a',
#                              'f31573b7-b894-414b-a421-b242aeffcb8a',
#                              '22c917a7-2bcf-4dca-b0e9-c155c7ed4ec6',
#                              '3cbbcba5-ea73-405f-b7d8-9c49ef1e9e1d',
#                              '8d07298c-096e-44ff-8029-d1481d5ccadc',
#                              '62db7b42-5185-4e75-bd72-957b29c2c254',
#                              '5ed44f2d-8c6c-4128-89c1-792cc95a7a96',
#                              '777353eb-973e-48e4-a366-7a4f7487a76a',
#                              'b62ce1ea-7b9a-4751-950a-fe5dd932cfd2',
#                              '126b4746-7d6f-462f-9d4c-0b6bb60b7d16',
#                              'b0cff9c8-7c4a-4214-bf85-bf73fe42d42b'],
#                      'Type': 'CHILD'}],
#   'Text': 'The above application would be addressed to the Joint Secretary '
#           '(Interna'},
#  {'BlockType': 'LINE',
#   'Confidence': 98.17381286621094,
#   'Geometry': {'BoundingBox': {'Height': 0.01914561539888382,
#                                'Left': 0.17180705070495605,
#                                'Top': 0.04696277529001236,
#                                'Width': 0.6764228343963623},
#                'Polygon': [{'X': 0.17180705070495605, 'Y': 0.04696277529001236},
#                            {'X': 0.8482298851013184, 'Y': 0.04696277529001236},
#                            {'X': 0.8482298851013184, 'Y': 0.06610839068889618},
#                            {'X': 0.17180705070495605,
#                             'Y': 0.06610839068889618}]},
#   'Id': '57148d7a-d082-4217-9fe1-ff323edde366',
#   'Relationships': [{'Ids': ['ee5a061b-87dd-4d7d-aba1-aeffbb388249',
#                              '60c46ef8-b870-4647-8080-bee593a11df8',
#                              '910b4a05-6efc-43bb-b159-8779a27457f7',
#                              '2c21dc9c-30ef-41bd-afa7-6597b1424de3',
#                              'a6b3a758-5bfe-4961-ad71-9b8b37ce2d50',
#                              '310752f3-ac13-4ad7-9031-ee816e113f5f',
#                              'a78c2e23-6270-45b3-b2e6-072ac3923236',
#                              'a95b47aa-9d98-454b-b230-6754166e3404',
#                              '343abab1-53c6-4438-9d7d-b0c1e6a02c34',
#                              '454afe2c-026d-4031-86a0-604727a2d98f',
#                              '9b0a399e-2226-43b7-87e7-115548409792'],
#                      'Type': 'CHILD'}],
#   'Text': 'Security) Ministry of Home Affairs, South Block. New Delhi. The '
#           'relevant'},
#  {'BlockType': 'LINE',
#   'Confidence': 97.79662322998047,
#   'Geometry': {'BoundingBox': {'Height': 0.018621953204274178,
#                                'Left': 0.17331749200820923,
#                                'Top': 0.06777013838291168,
#                                'Width': 0.21785642206668854},
#                'Polygon': [{'X': 0.17331749200820923, 'Y': 0.06777013838291168},
#                            {'X': 0.39117392897605896, 'Y': 0.06777013838291168},
#                            {'X': 0.39117392897605896, 'Y': 0.08639208972454071},
#                            {'X': 0.17331749200820923,
#                             'Y': 0.08639208972454071}]},
#   'Id': 'a290a06e-3ad9-409b-b46c-e4399afb86d0',
#   'Relationships': [{'Ids': ['2553a46e-b92d-4ee0-b9d4-390ab7da388b',
#                              'b58f2a85-735b-4b55-b6ab-985753a92fc6',
#                              '9399b1ff-c56b-4543-a121-f5557de7d01f'],
#                      'Type': 'CHILD'}],
#   'Text': 'proformas as follows'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.65118408203125,
#   'Geometry': {'BoundingBox': {'Height': 0.01400718092918396,
#                                'Left': 0.7129092812538147,
#                                'Top': 0.08842270076274872,
#                                'Width': 0.13515245914459229},
#                'Polygon': [{'X': 0.7129092812538147, 'Y': 0.08842270076274872},
#                            {'X': 0.848061740398407, 'Y': 0.08842270076274872},
#                            {'X': 0.848061740398407, 'Y': 0.10242988169193268},
#                            {'X': 0.7129092812538147,
#                             'Y': 0.10242988169193268}]},
#   'Id': '95dfbf01-92a7-4e4a-896b-055edee97843',
#   'Relationships': [{'Ids': ['db11d63f-8b9e-4021-9232-7cd3b555f2ac'],
#                      'Type': 'CHILD'}],
#   'Text': 'PROFORMA-I'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.27304077148438,
#   'Geometry': {'BoundingBox': {'Height': 0.014521840028464794,
#                                'Left': 0.25832295417785645,
#                                'Top': 0.12709583342075348,
#                                'Width': 0.5046296715736389},
#                'Polygon': [{'X': 0.25832295417785645, 'Y': 0.12709583342075348},
#                            {'X': 0.7629526257514954, 'Y': 0.12709583342075348},
#                            {'X': 0.7629526257514954, 'Y': 0.14161767065525055},
#                            {'X': 0.25832295417785645,
#                             'Y': 0.14161767065525055}]},
#   'Id': '38a4c4fb-56ba-4464-b05e-1fd95bc05bdf',
#   'Relationships': [{'Ids': ['8a80a5f2-a37d-4a0a-9044-001d57980a3c',
#                              '4e535be5-338a-4ece-a785-dbeb829cfe92',
#                              '73c32d2a-9e8a-486a-be41-e3f039b610bf',
#                              'f62ae17b-e733-4083-93ae-9611b3949fd6',
#                              '2ae1eb16-c028-46d2-8ec7-05c89f131902',
#                              'a5ba858d-441a-4cc4-ba7e-e14fd3c93922'],
#                      'Type': 'CHILD'}],
#   'Text': 'DETAILS ABOUT DIRECTOR OF INDIAN COMPANY'},
#  {'BlockType': 'LINE',
#   'Confidence': 80.18140411376953,
#   'Geometry': {'BoundingBox': {'Height': 0.014130979776382446,
#                                'Left': 0.17261740565299988,
#                                'Top': 0.16657836735248566,
#                                'Width': 0.05613653361797333},
#                'Polygon': [{'X': 0.17261740565299988, 'Y': 0.16657836735248566},
#                            {'X': 0.2287539392709732, 'Y': 0.16657836735248566},
#                            {'X': 0.2287539392709732, 'Y': 0.1807093471288681},
#                            {'X': 0.17261740565299988,
#                             'Y': 0.1807093471288681}]},
#   'Id': '10cb6836-3714-4f82-869c-ae876cd9b7d3',
#   'Relationships': [{'Ids': ['269de9e4-a099-4b86-82cb-85be04919e84'],
#                      'Type': 'CHILD'}],
#   'Text': 'SLNo.'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.28270721435547,
#   'Geometry': {'BoundingBox': {'Height': 0.014412582851946354,
#                                'Left': 0.24421969056129456,
#                                'Top': 0.16630882024765015,
#                                'Width': 0.221112459897995},
#                'Polygon': [{'X': 0.24421969056129456, 'Y': 0.16630882024765015},
#                            {'X': 0.46533215045928955, 'Y': 0.16630882024765015},
#                            {'X': 0.46533215045928955, 'Y': 0.18072140216827393},
#                            {'X': 0.24421969056129456,
#                             'Y': 0.18072140216827393}]},
#   'Id': '37ad900d-8129-41f9-a935-11b1b6c6b428',
#   'Relationships': [{'Ids': ['cd5eba1d-383e-477c-ab57-36ce62c01f0c',
#                              '265988ce-1f4c-4e84-94d5-c855921d3758',
#                              '68a9525e-420a-4b08-81c3-67e70ab0b501',
#                              '76c89c32-0600-40e7-8087-d80a13be3a23'],
#                      'Type': 'CHILD'}],
#   'Text': 'Particulars of Board of'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.35668182373047,
#   'Geometry': {'BoundingBox': {'Height': 0.014234736561775208,
#                                'Left': 0.630675733089447,
#                                'Top': 0.16710425913333893,
#                                'Width': 0.06455910205841064},
#                'Polygon': [{'X': 0.630675733089447, 'Y': 0.16710425913333893},
#                            {'X': 0.6952348351478577, 'Y': 0.16710425913333893},
#                            {'X': 0.6952348351478577, 'Y': 0.18133899569511414},
#                            {'X': 0.630675733089447, 'Y': 0.18133899569511414}]},
#   'Id': '56477e7a-eb2d-4151-bb7a-1177e82edc81',
#   'Relationships': [{'Ids': ['f80f2888-1226-42ac-a23c-8ac4672b23ae'],
#                      'Type': 'CHILD'}],
#   'Text': 'Details'},
#  {'BlockType': 'LINE',
#   'Confidence': 96.95989227294922,
#   'Geometry': {'BoundingBox': {'Height': 0.014642193913459778,
#                                'Left': 0.24474509060382843,
#                                'Top': 0.18555212020874023,
#                                'Width': 0.0844200998544693},
#                'Polygon': [{'X': 0.24474509060382843, 'Y': 0.18555212020874023},
#                            {'X': 0.32916519045829773, 'Y': 0.18555212020874023},
#                            {'X': 0.32916519045829773, 'Y': 0.2001943141222},
#                            {'X': 0.24474509060382843, 'Y': 0.2001943141222}]},
#   'Id': 'e10584d7-d62a-48a6-a866-c6b33ca01da6',
#   'Relationships': [{'Ids': ['05b69f67-c20a-4f5e-99a8-91713e2be609'],
#                      'Type': 'CHILD'}],
#   'Text': 'Directors'},
#  {'BlockType': 'LINE',
#   'Confidence': 98.66069030761719,
#   'Geometry': {'BoundingBox': {'Height': 0.016360491514205933,
#                                'Left': 0.19394057989120483,
#                                'Top': 0.20740334689617157,
#                                'Width': 0.012569144368171692},
#                'Polygon': [{'X': 0.19394057989120483, 'Y': 0.20740334689617157},
#                            {'X': 0.20650972425937653, 'Y': 0.20740334689617157},
#                            {'X': 0.20650972425937653, 'Y': 0.2237638384103775},
#                            {'X': 0.19394057989120483,
#                             'Y': 0.2237638384103775}]},
#   'Id': 'ed8c778b-b431-480f-a383-eca9a933031e',
#   'Relationships': [{'Ids': ['349db779-0785-4404-9ed0-0482f17ac7d9'],
#                      'Type': 'CHILD'}],
#   'Text': 'i)'},
#  {'BlockType': 'LINE',
#   'Confidence': 92.48895263671875,
#   'Geometry': {'BoundingBox': {'Height': 0.014157990925014019,
#                                'Left': 0.24560220539569855,
#                                'Top': 0.20674338936805725,
#                                'Width': 0.10947307199239731},
#                'Polygon': [{'X': 0.24560220539569855, 'Y': 0.20674338936805725},
#                            {'X': 0.35507526993751526, 'Y': 0.20674338936805725},
#                            {'X': 0.35507526993751526, 'Y': 0.22090138494968414},
#                            {'X': 0.24560220539569855,
#                             'Y': 0.22090138494968414}]},
#   'Id': '95adeeb4-422c-498f-a6cc-256ed00ffb3c',
#   'Relationships': [{'Ids': ['ae5c65ce-6f28-443c-baa8-a26c8b513f20',
#                              '1227c912-fabb-46f1-b00d-bb31203c5d19',
#                              '767f6702-a3de-4baa-ba77-385f14a59172'],
#                      'Type': 'CHILD'}],
#   'Text': 'Name in full'},
#  {'BlockType': 'LINE',
#   'Confidence': 87.60205841064453,
#   'Geometry': {'BoundingBox': {'Height': 0.017018437385559082,
#                                'Left': 0.19152842462062836,
#                                'Top': 0.22833962738513947,
#                                'Width': 0.01928851008415222},
#                'Polygon': [{'X': 0.19152842462062836, 'Y': 0.22833962738513947},
#                            {'X': 0.21081693470478058, 'Y': 0.22833962738513947},
#                            {'X': 0.21081693470478058, 'Y': 0.24535806477069855},
#                            {'X': 0.19152842462062836,
#                             'Y': 0.24535806477069855}]},
#   'Id': 'd48150b1-138c-496c-a2d4-8b8c9f057a4d',
#   'Relationships': [{'Ids': ['06695abc-4701-4fba-ab2b-bb104987d741'],
#                      'Type': 'CHILD'}],
#   'Text': 'ii)'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.0678939819336,
#   'Geometry': {'BoundingBox': {'Height': 0.016628116369247437,
#                                'Left': 0.24423862993717194,
#                                'Top': 0.22796256840229034,
#                                'Width': 0.11494578421115875},
#                'Polygon': [{'X': 0.24423862993717194, 'Y': 0.22796256840229034},
#                            {'X': 0.3591844141483307, 'Y': 0.22796256840229034},
#                            {'X': 0.3591844141483307, 'Y': 0.24459068477153778},
#                            {'X': 0.24423862993717194,
#                             'Y': 0.24459068477153778}]},
#   'Id': 'b11f38e6-4080-4dca-be38-d8c4c74eaf39',
#   'Relationships': [{'Ids': ['de5ea658-f077-48e1-9a45-64610bd75612'],
#                      'Type': 'CHILD'}],
#   'Text': 'Qualification'},
#  {'BlockType': 'LINE',
#   'Confidence': 44.47526931762695,
#   'Geometry': {'BoundingBox': {'Height': 0.01757223904132843,
#                                'Left': 0.18827834725379944,
#                                'Top': 0.2488756626844406,
#                                'Width': 0.024724051356315613},
#                'Polygon': [{'X': 0.18827834725379944, 'Y': 0.2488756626844406},
#                            {'X': 0.21300239861011505, 'Y': 0.2488756626844406},
#                            {'X': 0.21300239861011505, 'Y': 0.26644790172576904},
#                            {'X': 0.18827834725379944,
#                             'Y': 0.26644790172576904}]},
#   'Id': '6c7b6321-a8e0-4f09-80dd-9d6ce6106508',
#   'Relationships': [{'Ids': ['d5eb9e3b-e281-447a-84d8-05dd7a6a137b'],
#                      'Type': 'CHILD'}],
#   'Text': 'his)'},
#  {'BlockType': 'LINE',
#   'Confidence': 95.35761260986328,
#   'Geometry': {'BoundingBox': {'Height': 0.018433690071105957,
#                                'Left': 0.2454943209886551,
#                                'Top': 0.24827715754508972,
#                                'Width': 0.18230070173740387},
#                'Polygon': [{'X': 0.2454943209886551, 'Y': 0.24827715754508972},
#                            {'X': 0.42779502272605896, 'Y': 0.24827715754508972},
#                            {'X': 0.42779502272605896, 'Y': 0.2667108476161957},
#                            {'X': 0.2454943209886551, 'Y': 0.2667108476161957}]},
#   'Id': 'e8bd4d35-82e8-42cf-9567-0b286ceeeb25',
#   'Relationships': [{'Ids': ['e9b9928f-4b85-4e52-a522-573d306c0b70',
#                              '1acb4269-81cd-492d-bd30-85e99652164d',
#                              'ed6bf49c-59a9-49f5-86fb-5ff32b8f5fe9',
#                              '29b8ed76-8662-4763-9b04-fc7876b91623',
#                              'b6a0f9a9-d55d-4a61-8e07-010be7868ca5'],
#                      'Type': 'CHILD'}],
#   'Text': 'Date & place of Birth'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.62498474121094,
#   'Geometry': {'BoundingBox': {'Height': 0.01690959930419922,
#                                'Left': 0.1883777678012848,
#                                'Top': 0.2703087627887726,
#                                'Width': 0.024434685707092285},
#                'Polygon': [{'X': 0.1883777678012848, 'Y': 0.2703087627887726},
#                            {'X': 0.21281245350837708, 'Y': 0.2703087627887726},
#                            {'X': 0.21281245350837708, 'Y': 0.2872183620929718},
#                            {'X': 0.1883777678012848, 'Y': 0.2872183620929718}]},
#   'Id': 'f78be44a-f59d-4f3e-872a-84b2daffc93d',
#   'Relationships': [{'Ids': ['ff097b23-68d9-4a67-aa30-5a90f42b109a'],
#                      'Type': 'CHILD'}],
#   'Text': 'iv)'},
#  {'BlockType': 'LINE',
#   'Confidence': 98.96829223632812,
#   'Geometry': {'BoundingBox': {'Height': 0.014306724071502686,
#                                'Left': 0.2456064075231552,
#                                'Top': 0.2695038318634033,
#                                'Width': 0.18399982154369354},
#                'Polygon': [{'X': 0.2456064075231552, 'Y': 0.2695038318634033},
#                            {'X': 0.42960622906684875, 'Y': 0.2695038318634033},
#                            {'X': 0.42960622906684875, 'Y': 0.283810555934906},
#                            {'X': 0.2456064075231552, 'Y': 0.283810555934906}]},
#   'Id': '9d6b1e5d-9d1e-4d9d-9c20-85731796e70b',
#   'Relationships': [{'Ids': ['15bcb3e2-db73-4dd8-9219-cc5159dafb92',
#                              'd4e190a8-2529-4da3-8d3f-04381adfa32f',
#                              'c013dae3-2c08-4155-8e6b-55a769119fb3',
#                              'dd9c4590-a8af-4f73-8908-c17ee2b4688c'],
#                      'Type': 'CHILD'}],
#   'Text': "Father's Name in full"},
#  {'BlockType': 'LINE',
#   'Confidence': 75.65301513671875,
#   'Geometry': {'BoundingBox': {'Height': 0.01620924472808838,
#                                'Left': 0.19118179380893707,
#                                'Top': 0.2914377450942993,
#                                'Width': 0.019303739070892334},
#                'Polygon': [{'X': 0.19118179380893707, 'Y': 0.2914377450942993},
#                            {'X': 0.2104855328798294, 'Y': 0.2914377450942993},
#                            {'X': 0.2104855328798294, 'Y': 0.3076469898223877},
#                            {'X': 0.19118179380893707,
#                             'Y': 0.3076469898223877}]},
#   'Id': 'bf65abbc-7492-4ec2-a291-e9850c7d33d7',
#   'Relationships': [{'Ids': ['24c41115-29af-40f6-8d3e-018209b521a8'],
#                      'Type': 'CHILD'}],
#   'Text': 'V)'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.60710906982422,
#   'Geometry': {'BoundingBox': {'Height': 0.017082810401916504,
#                                'Left': 0.2449604719877243,
#                                'Top': 0.29037803411483765,
#                                'Width': 0.09956131875514984},
#                'Polygon': [{'X': 0.2449604719877243, 'Y': 0.29037803411483765},
#                            {'X': 0.34452179074287415, 'Y': 0.29037803411483765},
#                            {'X': 0.34452179074287415, 'Y': 0.30746084451675415},
#                            {'X': 0.2449604719877243,
#                             'Y': 0.30746084451675415}]},
#   'Id': 'f6b5d50e-f916-4ee8-b2cd-d5b773e3fd43',
#   'Relationships': [{'Ids': ['bfa44cf0-a486-42d7-be1e-16f105a108df'],
#                      'Type': 'CHILD'}],
#   'Text': 'Nationality'},
#  {'BlockType': 'LINE',
#   'Confidence': 94.07867431640625,
#   'Geometry': {'BoundingBox': {'Height': 0.01679965853691101,
#                                'Left': 0.18843011558055878,
#                                'Top': 0.3121754825115204,
#                                'Width': 0.02451436221599579},
#                'Polygon': [{'X': 0.18843011558055878, 'Y': 0.3121754825115204},
#                            {'X': 0.21294447779655457, 'Y': 0.3121754825115204},
#                            {'X': 0.21294447779655457, 'Y': 0.3289751410484314},
#                            {'X': 0.18843011558055878,
#                             'Y': 0.3289751410484314}]},
#   'Id': '96bf9064-3c6c-4253-bde2-8587e9918d54',
#   'Relationships': [{'Ids': ['e609827e-e1cb-468d-894f-8c61e04896ae'],
#                      'Type': 'CHILD'}],
#   'Text': 'vi)'},
#  {'BlockType': 'LINE',
#   'Confidence': 97.83113098144531,
#   'Geometry': {'BoundingBox': {'Height': 0.01407137606292963,
#                                'Left': 0.2446511834859848,
#                                'Top': 0.31105777621269226,
#                                'Width': 0.1268307864665985},
#                'Polygon': [{'X': 0.2446511834859848, 'Y': 0.31105777621269226},
#                            {'X': 0.3714819550514221, 'Y': 0.31105777621269226},
#                            {'X': 0.3714819550514221, 'Y': 0.3251291513442993},
#                            {'X': 0.2446511834859848, 'Y': 0.3251291513442993}]},
#   'Id': 'a5ee42e7-730f-4ef9-a75a-a08711ea5dc7',
#   'Relationships': [{'Ids': ['ec607301-854f-45fb-a029-15b7e81e4c3f',
#                              '0b9bb289-6d9d-4887-be8f-4742f88eaa81'],
#                      'Type': 'CHILD'}],
#   'Text': 'Office address'},
#  {'BlockType': 'LINE',
#   'Confidence': 96.42147064208984,
#   'Geometry': {'BoundingBox': {'Height': 0.01667565107345581,
#                                'Left': 0.18535426259040833,
#                                'Top': 0.3324514925479889,
#                                'Width': 0.030480369925498962},
#                'Polygon': [{'X': 0.18535426259040833, 'Y': 0.3324514925479889},
#                            {'X': 0.2158346325159073, 'Y': 0.3324514925479889},
#                            {'X': 0.2158346325159073, 'Y': 0.3491271436214447},
#                            {'X': 0.18535426259040833,
#                             'Y': 0.3491271436214447}]},
#   'Id': '9efe6adf-f9c3-42b5-80bb-10add3e02ff5',
#   'Relationships': [{'Ids': ['732fdf67-41e4-4e97-8ca0-255c621d5d9a'],
#                      'Type': 'CHILD'}],
#   'Text': 'vii)'},
#  {'BlockType': 'LINE',
#   'Confidence': 94.71946716308594,
#   'Geometry': {'BoundingBox': {'Height': 0.013873696327209473,
#                                'Left': 0.24433451890945435,
#                                'Top': 0.332417756319046,
#                                'Width': 0.16902485489845276},
#                'Polygon': [{'X': 0.24433451890945435, 'Y': 0.332417756319046},
#                            {'X': 0.4133593738079071, 'Y': 0.332417756319046},
#                            {'X': 0.4133593738079071, 'Y': 0.3462914526462555},
#                            {'X': 0.24433451890945435,
#                             'Y': 0.3462914526462555}]},
#   'Id': '508a50a5-2a08-4074-91d1-8dcdec2821bf',
#   'Relationships': [{'Ids': ['de5feda5-0b0f-4e55-9a04-efffa96527ac',
#                              '40953484-90f1-46f7-a10f-b175bdc34b66'],
#                      'Type': 'CHILD'}],
#   'Text': 'Permanent addresss'},
#  {'BlockType': 'LINE',
#   'Confidence': 84.44422149658203,
#   'Geometry': {'BoundingBox': {'Height': 0.01723659038543701,
#                                'Left': 0.18223458528518677,
#                                'Top': 0.35283026099205017,
#                                'Width': 0.035588204860687256},
#                'Polygon': [{'X': 0.18223458528518677, 'Y': 0.35283026099205017},
#                            {'X': 0.21782279014587402, 'Y': 0.35283026099205017},
#                            {'X': 0.21782279014587402, 'Y': 0.3700668513774872},
#                            {'X': 0.18223458528518677,
#                             'Y': 0.3700668513774872}]},
#   'Id': '37ff3324-be95-4e05-a9bd-baf17ef976de',
#   'Relationships': [{'Ids': ['cf64d8e1-c5fb-4738-bb10-143e84d2ffec'],
#                      'Type': 'CHILD'}],
#   'Text': 'vini)'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.10946655273438,
#   'Geometry': {'BoundingBox': {'Height': 0.013922154903411865,
#                                'Left': 0.24461935460567474,
#                                'Top': 0.35304614901542664,
#                                'Width': 0.21062122285366058},
#                'Polygon': [{'X': 0.24461935460567474, 'Y': 0.35304614901542664},
#                            {'X': 0.4552405774593353, 'Y': 0.35304614901542664},
#                            {'X': 0.4552405774593353, 'Y': 0.3669683039188385},
#                            {'X': 0.24461935460567474,
#                             'Y': 0.3669683039188385}]},
#   'Id': '698a3890-7f00-405e-a78f-00e9d146ad5d',
#   'Relationships': [{'Ids': ['fb4b4e0d-9224-41af-a9d8-d4f0e6ee25a4',
#                              '5d4e6024-3e9f-4b67-8bfa-b7d967a42863',
#                              'ce1b3748-be00-43b9-85aa-a62c0787fcc8',
#                              'ec04f2bc-3343-4bb1-8a5a-7a8b727d1237'],
#                      'Type': 'CHILD'}],
#   'Text': 'Present address in India'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.19770812988281,
#   'Geometry': {'BoundingBox': {'Height': 0.017595887184143066,
#                                'Left': 0.18863745033740997,
#                                'Top': 0.37383607029914856,
#                                'Width': 0.02416709065437317},
#                'Polygon': [{'X': 0.18863745033740997, 'Y': 0.37383607029914856},
#                            {'X': 0.21280454099178314, 'Y': 0.37383607029914856},
#                            {'X': 0.21280454099178314, 'Y': 0.3914319574832916},
#                            {'X': 0.18863745033740997,
#                             'Y': 0.3914319574832916}]},
#   'Id': '2ecd9486-64bd-42c4-87c3-583b4dcce12d',
#   'Relationships': [{'Ids': ['60d284f3-4410-4608-9954-a36944d03042'],
#                      'Type': 'CHILD'}],
#   'Text': 'ix)'},
#  {'BlockType': 'LINE',
#   'Confidence': 94.06587219238281,
#   'Geometry': {'BoundingBox': {'Height': 0.018213361501693726,
#                                'Left': 0.24507127702236176,
#                                'Top': 0.3739015460014343,
#                                'Width': 0.20101699233055115},
#                'Polygon': [{'X': 0.24507127702236176, 'Y': 0.3739015460014343},
#                            {'X': 0.4460882842540741, 'Y': 0.3739015460014343},
#                            {'X': 0.4460882842540741, 'Y': 0.39211490750312805},
#                            {'X': 0.24507127702236176,
#                             'Y': 0.39211490750312805}]},
#   'Id': '05674d1e-ef39-4b2d-ace0-eb9a9003b2bc',
#   'Relationships': [{'Ids': ['84589a8e-599a-4ea8-b636-539a4ea5a8c4',
#                              'c636b300-bec5-49f4-887d-5abb7562dbf5',
#                              '07923250-0082-4e1a-8545-0c7d738e36ec',
#                              'd70581f0-5c3f-4fce-a9f7-9a2605d1a0d0'],
#                      'Type': 'CHILD'}],
#   'Text': 'Passport No. and place'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.28819274902344,
#   'Geometry': {'BoundingBox': {'Height': 0.014048910699784756,
#                                'Left': 0.24459229409694672,
#                                'Top': 0.3936375081539154,
#                                'Width': 0.06821686774492264},
#                'Polygon': [{'X': 0.24459229409694672, 'Y': 0.3936375081539154},
#                            {'X': 0.31280916929244995, 'Y': 0.3936375081539154},
#                            {'X': 0.31280916929244995, 'Y': 0.40768641233444214},
#                            {'X': 0.24459229409694672,
#                             'Y': 0.40768641233444214}]},
#   'Id': 'a3dd4dd1-a905-44cb-894d-2037a195f15f',
#   'Relationships': [{'Ids': ['d1f669f1-e1ce-4ba1-ba07-4ba8ab140f26',
#                              '403f03a8-f9f0-4acb-8866-6e455f3a1de2'],
#                      'Type': 'CHILD'}],
#   'Text': 'of Issue'},
#  {'BlockType': 'LINE',
#   'Confidence': 94.71595764160156,
#   'Geometry': {'BoundingBox': {'Height': 0.017330139875411987,
#                                'Left': 0.19173453748226166,
#                                'Top': 0.41544491052627563,
#                                'Width': 0.017524227499961853},
#                'Polygon': [{'X': 0.19173453748226166, 'Y': 0.41544491052627563},
#                            {'X': 0.2092587649822235, 'Y': 0.41544491052627563},
#                            {'X': 0.2092587649822235, 'Y': 0.4327750504016876},
#                            {'X': 0.19173453748226166,
#                             'Y': 0.4327750504016876}]},
#   'Id': '40a014eb-5722-456b-9760-bc13e9784f31',
#   'Relationships': [{'Ids': ['a9882444-2f64-433e-8440-910f794be84b'],
#                      'Type': 'CHILD'}],
#   'Text': 'x)'},
#  {'BlockType': 'LINE',
#   'Confidence': 94.14862823486328,
#   'Geometry': {'BoundingBox': {'Height': 0.017903931438922882,
#                                'Left': 0.2453305572271347,
#                                'Top': 0.41529425978660583,
#                                'Width': 0.16596612334251404},
#                'Polygon': [{'X': 0.2453305572271347, 'Y': 0.41529425978660583},
#                            {'X': 0.41129669547080994, 'Y': 0.41529425978660583},
#                            {'X': 0.41129669547080994, 'Y': 0.4331981837749481},
#                            {'X': 0.2453305572271347, 'Y': 0.4331981837749481}]},
#   'Id': 'a60ddca6-bbee-4055-8714-559714a24813',
#   'Relationships': [{'Ids': ['7ce5181e-0dff-4948-8a94-ad748133027f',
#                              'f1ec27df-554d-4efe-b0f8-89d045b0ab93'],
#                      'Type': 'CHILD'}],
#   'Text': 'Present occupation'},
#  {'BlockType': 'LINE',
#   'Confidence': 79.33411407470703,
#   'Geometry': {'BoundingBox': {'Height': 0.018147319555282593,
#                                'Left': 0.18894226849079132,
#                                'Top': 0.43627503514289856,
#                                'Width': 0.023722097277641296},
#                'Polygon': [{'X': 0.18894226849079132, 'Y': 0.43627503514289856},
#                            {'X': 0.21266436576843262, 'Y': 0.43627503514289856},
#                            {'X': 0.21266436576843262, 'Y': 0.45442235469818115},
#                            {'X': 0.18894226849079132,
#                             'Y': 0.45442235469818115}]},
#   'Id': '0cc9af7d-9573-4587-86e9-c188301b5aa2',
#   'Relationships': [{'Ids': ['4ee19ab4-cd9b-4285-ac12-68488973b05c'],
#                      'Type': 'CHILD'}],
#   'Text': 'xi)'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.54731750488281,
#   'Geometry': {'BoundingBox': {'Height': 0.014938712120056152,
#                                'Left': 0.24545429646968842,
#                                'Top': 0.4357392191886902,
#                                'Width': 0.06186439096927643},
#                'Polygon': [{'X': 0.24545429646968842, 'Y': 0.4357392191886902},
#                            {'X': 0.30731868743896484, 'Y': 0.4357392191886902},
#                            {'X': 0.30731868743896484, 'Y': 0.45067793130874634},
#                            {'X': 0.24545429646968842,
#                             'Y': 0.45067793130874634}]},
#   'Id': '30845097-51e1-4d84-8044-7c6e72baf4e8',
#   'Relationships': [{'Ids': ['099c1f31-ca4f-4e49-8b4f-1136c6a2e472'],
#                      'Type': 'CHILD'}],
#   'Text': 'Banker'},
#  {'BlockType': 'LINE',
#   'Confidence': 80.8792953491211,
#   'Geometry': {'BoundingBox': {'Height': 0.01700761914253235,
#                                'Left': 0.1864558607339859,
#                                'Top': 0.4577489495277405,
#                                'Width': 0.028867587447166443},
#                'Polygon': [{'X': 0.1864558607339859, 'Y': 0.4577489495277405},
#                            {'X': 0.21532344818115234, 'Y': 0.4577489495277405},
#                            {'X': 0.21532344818115234, 'Y': 0.4747565686702728},
#                            {'X': 0.1864558607339859, 'Y': 0.4747565686702728}]},
#   'Id': 'eb5b15a8-d212-4dc0-8c60-4b11d1b970af',
#   'Relationships': [{'Ids': ['074ff709-5940-4f3f-bf90-d4844d0f5f62'],
#                      'Type': 'CHILD'}],
#   'Text': 'xil)'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.666748046875,
#   'Geometry': {'BoundingBox': {'Height': 0.018215207383036613,
#                                'Left': 0.24508576095104218,
#                                'Top': 0.45710381865501404,
#                                'Width': 0.19703413546085358},
#                'Polygon': [{'X': 0.24508576095104218, 'Y': 0.45710381865501404},
#                            {'X': 0.44211989641189575, 'Y': 0.45710381865501404},
#                            {'X': 0.44211989641189575, 'Y': 0.4753190279006958},
#                            {'X': 0.24508576095104218,
#                             'Y': 0.4753190279006958}]},
#   'Id': '17cf63d4-97f3-425f-996a-14c3eb4d8167',
#   'Relationships': [{'Ids': ['82925bd1-c570-4228-ba49-d18766569cb7',
#                              'c3cee398-d17a-4e9f-bf03-1d314b132fcd',
#                              '6f70d0cd-f29f-498c-a866-d2a016e246da'],
#                      'Type': 'CHILD'}],
#   'Text': 'Any other information'},
#  {'BlockType': 'LINE',
#   'Confidence': 92.04144287109375,
#   'Geometry': {'BoundingBox': {'Height': 0.014669179916381836,
#                                'Left': 0.707362711429596,
#                                'Top': 0.5791321396827698,
#                                'Width': 0.1384093165397644},
#                'Polygon': [{'X': 0.707362711429596, 'Y': 0.5791321396827698},
#                            {'X': 0.8457720279693604, 'Y': 0.5791321396827698},
#                            {'X': 0.8457720279693604, 'Y': 0.5938013195991516},
#                            {'X': 0.707362711429596, 'Y': 0.5938013195991516}]},
#   'Id': 'a0e18886-4e83-4d83-bcd0-c0c75b3ae21b',
#   'Relationships': [{'Ids': ['35b7e299-04f0-4518-9780-1d21ee74a350'],
#                      'Type': 'CHILD'}],
#   'Text': 'PROFORMA-II'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.35279846191406,
#   'Geometry': {'BoundingBox': {'Height': 0.015090377070009708,
#                                'Left': 0.2515445053577423,
#                                'Top': 0.6179522275924683,
#                                'Width': 0.5180001854896545},
#                'Polygon': [{'X': 0.2515445053577423, 'Y': 0.6179522275924683},
#                            {'X': 0.7695446610450745, 'Y': 0.6179522275924683},
#                            {'X': 0.7695446610450745, 'Y': 0.633042573928833},
#                            {'X': 0.2515445053577423, 'Y': 0.633042573928833}]},
#   'Id': '3cfb179d-9de4-4f3f-ad54-6846b9f9a1d9',
#   'Relationships': [{'Ids': ['3a54cb32-02ee-4eb9-9f56-4201a3366fb9',
#                              '13e3d30f-4dba-4980-b51c-4f88a05399d9',
#                              '148621a6-f704-44ba-bac5-929e0b16779a',
#                              '249545f6-4d18-46fa-a6c4-bfdffb1c8366',
#                              '2b438871-d285-443a-a1d8-87f7373590a3',
#                              '65e11daf-99cc-4378-9637-cc044f9247d4'],
#                      'Type': 'CHILD'}],
#   'Text': 'DETAILS ABOUT DIRECTOR OF FOREIGN COMPANY'},
#  {'BlockType': 'LINE',
#   'Confidence': 79.92192840576172,
#   'Geometry': {'BoundingBox': {'Height': 0.014497041702270508,
#                                'Left': 0.172969251871109,
#                                'Top': 0.6580012440681458,
#                                'Width': 0.0556873083114624},
#                'Polygon': [{'X': 0.172969251871109, 'Y': 0.6580012440681458},
#                            {'X': 0.2286565601825714, 'Y': 0.6580012440681458},
#                            {'X': 0.2286565601825714, 'Y': 0.6724982857704163},
#                            {'X': 0.172969251871109, 'Y': 0.6724982857704163}]},
#   'Id': 'c302cc98-2ffa-49e6-a1ca-7d0bd853a510',
#   'Relationships': [{'Ids': ['55f05efa-0de9-4b6a-a01b-c472a50c95b6'],
#                      'Type': 'CHILD'}],
#   'Text': 'SI.No.'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.66204071044922,
#   'Geometry': {'BoundingBox': {'Height': 0.014553290791809559,
#                                'Left': 0.24453052878379822,
#                                'Top': 0.6577404141426086,
#                                'Width': 0.2178296446800232},
#                'Polygon': [{'X': 0.24453052878379822, 'Y': 0.6577404141426086},
#                            {'X': 0.4623601734638214, 'Y': 0.6577404141426086},
#                            {'X': 0.4623601734638214, 'Y': 0.6722936630249023},
#                            {'X': 0.24453052878379822,
#                             'Y': 0.6722936630249023}]},
#   'Id': '393bb39e-ecbb-49e8-bcf8-66c47bdafa3b',
#   'Relationships': [{'Ids': ['ad34bb27-3eda-412f-a9de-e8bfa6ebb8df',
#                              'fcb300e7-f18d-4821-ae82-919d15da07cd',
#                              'b9d0b2ea-94ec-42fb-a2a7-44ec35c1d1bf',
#                              '651757c5-759c-42b9-a09d-79ada142bcef'],
#                      'Type': 'CHILD'}],
#   'Text': 'Particulars of Board of'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.77336120605469,
#   'Geometry': {'BoundingBox': {'Height': 0.013861298561096191,
#                                'Left': 0.6293635964393616,
#                                'Top': 0.6584780812263489,
#                                'Width': 0.06501853466033936},
#                'Polygon': [{'X': 0.6293635964393616, 'Y': 0.6584780812263489},
#                            {'X': 0.6943821310997009, 'Y': 0.6584780812263489},
#                            {'X': 0.6943821310997009, 'Y': 0.6723393797874451},
#                            {'X': 0.6293635964393616, 'Y': 0.6723393797874451}]},
#   'Id': '9e373ad9-4281-4d86-b7bb-7e746156dba8',
#   'Relationships': [{'Ids': ['ed832254-2741-4152-8ee9-78038cfcde40'],
#                      'Type': 'CHILD'}],
#   'Text': 'Details'},
#  {'BlockType': 'LINE',
#   'Confidence': 98.05443572998047,
#   'Geometry': {'BoundingBox': {'Height': 0.014435529708862305,
#                                'Left': 0.24569043517112732,
#                                'Top': 0.6776297688484192,
#                                'Width': 0.08273792266845703},
#                'Polygon': [{'X': 0.24569043517112732, 'Y': 0.6776297688484192},
#                            {'X': 0.32842835783958435, 'Y': 0.6776297688484192},
#                            {'X': 0.32842835783958435, 'Y': 0.6920652985572815},
#                            {'X': 0.24569043517112732,
#                             'Y': 0.6920652985572815}]},
#   'Id': '2c7ed73b-6e03-4092-a182-acde81d6c815',
#   'Relationships': [{'Ids': ['96bf98b2-b383-4484-9515-f2f1fd018466'],
#                      'Type': 'CHILD'}],
#   'Text': 'Directors'},
#  {'BlockType': 'LINE',
#   'Confidence': 79.185546875,
#   'Geometry': {'BoundingBox': {'Height': 0.017342567443847656,
#                                'Left': 0.19359593093395233,
#                                'Top': 0.7177345156669617,
#                                'Width': 0.01348036527633667},
#                'Polygon': [{'X': 0.19359593093395233, 'Y': 0.7177345156669617},
#                            {'X': 0.207076296210289, 'Y': 0.7177345156669617},
#                            {'X': 0.207076296210289, 'Y': 0.7350770831108093},
#                            {'X': 0.19359593093395233,
#                             'Y': 0.7350770831108093}]},
#   'Id': 'fba94e33-2496-4409-ae76-e6c511e2746f',
#   'Relationships': [{'Ids': ['2b6758ce-cb5a-4898-a79e-ce479960d4b5'],
#                      'Type': 'CHILD'}],
#   'Text': 'i)'},
#  {'BlockType': 'LINE',
#   'Confidence': 74.01073455810547,
#   'Geometry': {'BoundingBox': {'Height': 0.01487882249057293,
#                                'Left': 0.24476201832294464,
#                                'Top': 0.7169877290725708,
#                                'Width': 0.11062821000814438},
#                'Polygon': [{'X': 0.24476201832294464, 'Y': 0.7169877290725708},
#                            {'X': 0.3553902208805084, 'Y': 0.7169877290725708},
#                            {'X': 0.3553902208805084, 'Y': 0.7318665385246277},
#                            {'X': 0.24476201832294464,
#                             'Y': 0.7318665385246277}]},
#   'Id': 'b13f7a6c-4593-4582-8b9a-13fe502a28ba',
#   'Relationships': [{'Ids': ['7652116c-629b-4ec6-a40d-6370033ca937',
#                              'e5e360f8-e6f6-42c6-b48a-14b6efa69d7b',
#                              '171d0684-7b75-4a55-9ce5-76db3cd286d2'],
#                      'Type': 'CHILD'}],
#   'Text': 'Name in fall'},
#  {'BlockType': 'LINE',
#   'Confidence': 90.7743148803711,
#   'Geometry': {'BoundingBox': {'Height': 0.017152488231658936,
#                                'Left': 0.19163888692855835,
#                                'Top': 0.7388057112693787,
#                                'Width': 0.018838420510292053},
#                'Polygon': [{'X': 0.19163888692855835, 'Y': 0.7388057112693787},
#                            {'X': 0.2104773074388504, 'Y': 0.7388057112693787},
#                            {'X': 0.2104773074388504, 'Y': 0.7559581995010376},
#                            {'X': 0.19163888692855835,
#                             'Y': 0.7559581995010376}]},
#   'Id': 'c40ca0ec-66d8-47ea-92d3-7f9a81e8b542',
#   'Relationships': [{'Ids': ['b27d64c3-161d-4b97-bdef-fc14d5ed886b'],
#                      'Type': 'CHILD'}],
#   'Text': 'ii)'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.6029281616211,
#   'Geometry': {'BoundingBox': {'Height': 0.014512419700622559,
#                                'Left': 0.24519215524196625,
#                                'Top': 0.7382687926292419,
#                                'Width': 0.074082151055336},
#                'Polygon': [{'X': 0.24519215524196625, 'Y': 0.7382687926292419},
#                            {'X': 0.31927430629730225, 'Y': 0.7382687926292419},
#                            {'X': 0.31927430629730225, 'Y': 0.7527812123298645},
#                            {'X': 0.24519215524196625,
#                             'Y': 0.7527812123298645}]},
#   'Id': '7bbd2633-9d76-403e-9805-135642c82505',
#   'Relationships': [{'Ids': ['7b7995e7-50fc-4755-92eb-09d453301772'],
#                      'Type': 'CHILD'}],
#   'Text': 'Address'},
#  {'BlockType': 'LINE',
#   'Confidence': 64.80642700195312,
#   'Geometry': {'BoundingBox': {'Height': 0.017188429832458496,
#                                'Left': 0.18847784399986267,
#                                'Top': 0.7603040337562561,
#                                'Width': 0.024724498391151428},
#                'Polygon': [{'X': 0.18847784399986267, 'Y': 0.7603040337562561},
#                            {'X': 0.2132023423910141, 'Y': 0.7603040337562561},
#                            {'X': 0.2132023423910141, 'Y': 0.7774924635887146},
#                            {'X': 0.18847784399986267,
#                             'Y': 0.7774924635887146}]},
#   'Id': '9476edf0-e25e-4acf-a661-6b2b1f8834d3',
#   'Relationships': [{'Ids': ['373620c1-d2d4-4797-9244-961ad30f4da5'],
#                      'Type': 'CHILD'}],
#   'Text': 'lii)'},
#  {'BlockType': 'LINE',
#   'Confidence': 90.26385498046875,
#   'Geometry': {'BoundingBox': {'Height': 0.01856100559234619,
#                                'Left': 0.24553175270557404,
#                                'Top': 0.7583469748497009,
#                                'Width': 0.1821957379579544},
#                'Polygon': [{'X': 0.24553175270557404, 'Y': 0.7583469748497009},
#                            {'X': 0.42772749066352844, 'Y': 0.7583469748497009},
#                            {'X': 0.42772749066352844, 'Y': 0.7769079804420471},
#                            {'X': 0.24553175270557404,
#                             'Y': 0.7769079804420471}]},
#   'Id': '98a9967f-7175-4d9b-b994-bcecf6e77b19',
#   'Relationships': [{'Ids': ['698f8e69-a19e-44a4-ba0a-55a1961268d0',
#                              '6610f66d-1e44-409d-9583-12c24bfe570b',
#                              '137cce40-1ccf-4d78-8f59-6566984ba15a',
#                              '91e259dc-8b71-4dac-8100-46d9f9d00018',
#                              'b030a66d-dbd8-4dcd-aefa-a4918e38264a'],
#                      'Type': 'CHILD'}],
#   'Text': 'Date & place of Birth'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.84170532226562,
#   'Geometry': {'BoundingBox': {'Height': 0.016814231872558594,
#                                'Left': 0.18825030326843262,
#                                'Top': 0.7810195684432983,
#                                'Width': 0.02492941915988922},
#                'Polygon': [{'X': 0.18825030326843262, 'Y': 0.7810195684432983},
#                            {'X': 0.21317972242832184, 'Y': 0.7810195684432983},
#                            {'X': 0.21317972242832184, 'Y': 0.7978338003158569},
#                            {'X': 0.18825030326843262,
#                             'Y': 0.7978338003158569}]},
#   'Id': '32b3edf4-3edd-4bc2-8073-d2ee191da46d',
#   'Relationships': [{'Ids': ['9cbbbf8c-423f-495c-90d4-27cdbb3e6abe'],
#                      'Type': 'CHILD'}],
#   'Text': 'iv)'},
#  {'BlockType': 'LINE',
#   'Confidence': 79.75129699707031,
#   'Geometry': {'BoundingBox': {'Height': 0.01790863275527954,
#                                'Left': 0.2450219690799713,
#                                'Top': 0.780716061592102,
#                                'Width': 0.11200007796287537},
#                'Polygon': [{'X': 0.2450219690799713, 'Y': 0.780716061592102},
# ...
#                      'Type': 'CHILD'}]},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 1,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.05840826407074928,
#                                'Left': 0.16440127789974213,
#                                'Top': 0.6558571457862854,
#                                'Width': 0.07438138872385025},
#                'Polygon': [{'X': 0.16440127789974213, 'Y': 0.6558571457862854},
#                            {'X': 0.23878267407417297, 'Y': 0.6558571457862854},
#                            {'X': 0.23878267407417297, 'Y': 0.7142654061317444},
#                            {'X': 0.16440127789974213,
#                             'Y': 0.7142654061317444}]},
#   'Id': '1bda47c8-7f0c-40fa-9df8-320edeb6f746',
#   'Relationships': [{'Ids': ['55f05efa-0de9-4b6a-a01b-c472a50c95b6'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 1,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 2,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.05840826407074928,
#                                'Left': 0.23878267407417297,
#                                'Top': 0.6558571457862854,
#                                'Width': 0.23244184255599976},
#                'Polygon': [{'X': 0.23878267407417297, 'Y': 0.6558571457862854},
#                            {'X': 0.47122451663017273, 'Y': 0.6558571457862854},
#                            {'X': 0.47122451663017273, 'Y': 0.7142654061317444},
#                            {'X': 0.23878267407417297,
#                             'Y': 0.7142654061317444}]},
#   'Id': 'e7ec4696-5ef6-4f75-87df-0392f584b76e',
#   'Relationships': [{'Ids': ['ad34bb27-3eda-412f-a9de-e8bfa6ebb8df',
#                              'fcb300e7-f18d-4821-ae82-919d15da07cd',
#                              'b9d0b2ea-94ec-42fb-a2a7-44ec35c1d1bf',
#                              '651757c5-759c-42b9-a09d-79ada142bcef',
#                              '96bf98b2-b383-4484-9515-f2f1fd018466'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 1,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 3,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.05840826407074928,
#                                'Left': 0.47122451663017273,
#                                'Top': 0.6558571457862854,
#                                'Width': 0.38740307092666626},
#                'Polygon': [{'X': 0.47122451663017273, 'Y': 0.6558571457862854},
#                            {'X': 0.8586275577545166, 'Y': 0.6558571457862854},
#                            {'X': 0.8586275577545166, 'Y': 0.7142654061317444},
#                            {'X': 0.47122451663017273,
#                             'Y': 0.7142654061317444}]},
#   'Id': 'ce87d522-09cb-4e74-ba85-3d02d03a359b',
#   'Relationships': [{'Ids': ['ed832254-2741-4152-8ee9-78038cfcde40'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 1,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 1,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.021404270082712173,
#                                'Left': 0.16440127789974213,
#                                'Top': 0.7142654061317444,
#                                'Width': 0.07438138872385025},
#                'Polygon': [{'X': 0.16440127789974213, 'Y': 0.7142654061317444},
#                            {'X': 0.23878267407417297, 'Y': 0.7142654061317444},
#                            {'X': 0.23878267407417297, 'Y': 0.7356696724891663},
#                            {'X': 0.16440127789974213,
#                             'Y': 0.7356696724891663}]},
#   'Id': '982d4529-c4ba-46d3-83e2-4089862e66bd',
#   'Relationships': [{'Ids': ['2b6758ce-cb5a-4898-a79e-ce479960d4b5'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 2,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 2,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.021404270082712173,
#                                'Left': 0.23878267407417297,
#                                'Top': 0.7142654061317444,
#                                'Width': 0.23244184255599976},
#                'Polygon': [{'X': 0.23878267407417297, 'Y': 0.7142654061317444},
#                            {'X': 0.47122451663017273, 'Y': 0.7142654061317444},
#                            {'X': 0.47122451663017273, 'Y': 0.7356696724891663},
#                            {'X': 0.23878267407417297,
#                             'Y': 0.7356696724891663}]},
#   'Id': '808dac02-cf7a-4d71-9a34-e6805e1518ca',
#   'Relationships': [{'Ids': ['7652116c-629b-4ec6-a40d-6370033ca937',
#                              'e5e360f8-e6f6-42c6-b48a-14b6efa69d7b',
#                              '171d0684-7b75-4a55-9ce5-76db3cd286d2'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 2,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 3,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.021404270082712173,
#                                'Left': 0.47122451663017273,
#                                'Top': 0.7142654061317444,
#                                'Width': 0.38740307092666626},
#                'Polygon': [{'X': 0.47122451663017273, 'Y': 0.7142654061317444},
#                            {'X': 0.8586275577545166, 'Y': 0.7142654061317444},
#                            {'X': 0.8586275577545166, 'Y': 0.7356696724891663},
#                            {'X': 0.47122451663017273,
#                             'Y': 0.7356696724891663}]},
#   'Id': '55031864-cc0d-41d1-8639-d58fc9df6082',
#   'RowIndex': 2,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 1,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.021404270082712173,
#                                'Left': 0.16440127789974213,
#                                'Top': 0.7356696724891663,
#                                'Width': 0.07438138872385025},
#                'Polygon': [{'X': 0.16440127789974213, 'Y': 0.7356696724891663},
#                            {'X': 0.23878267407417297, 'Y': 0.7356696724891663},
#                            {'X': 0.23878267407417297, 'Y': 0.7570739984512329},
#                            {'X': 0.16440127789974213,
#                             'Y': 0.7570739984512329}]},
#   'Id': '28ef4692-1a6e-4e59-92a1-115bd31b1923',
#   'Relationships': [{'Ids': ['b27d64c3-161d-4b97-bdef-fc14d5ed886b'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 3,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 2,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.021404270082712173,
#                                'Left': 0.23878267407417297,
#                                'Top': 0.7356696724891663,
#                                'Width': 0.23244184255599976},
#                'Polygon': [{'X': 0.23878267407417297, 'Y': 0.7356696724891663},
#                            {'X': 0.47122451663017273, 'Y': 0.7356696724891663},
#                            {'X': 0.47122451663017273, 'Y': 0.7570739984512329},
#                            {'X': 0.23878267407417297,
#                             'Y': 0.7570739984512329}]},
#   'Id': '4f083776-7e94-4ee5-829f-d4aa47c66426',
#   'Relationships': [{'Ids': ['7b7995e7-50fc-4755-92eb-09d453301772'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 3,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 3,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.021404270082712173,
#                                'Left': 0.47122451663017273,
#                                'Top': 0.7356696724891663,
#                                'Width': 0.38740307092666626},
#                'Polygon': [{'X': 0.47122451663017273, 'Y': 0.7356696724891663},
#                            {'X': 0.8586275577545166, 'Y': 0.7356696724891663},
#                            {'X': 0.8586275577545166, 'Y': 0.7570739984512329},
#                            {'X': 0.47122451663017273,
#                             'Y': 0.7570739984512329}]},
#   'Id': '0ff9eb5d-c7e3-4dc4-84a1-f6f2479a096a',
#   'RowIndex': 3,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 1,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.020678702741861343,
#                                'Left': 0.16440127789974213,
#                                'Top': 0.7570739984512329,
#                                'Width': 0.07438138872385025},
#                'Polygon': [{'X': 0.16440127789974213, 'Y': 0.7570739984512329},
#                            {'X': 0.23878267407417297, 'Y': 0.7570739984512329},
#                            {'X': 0.23878267407417297, 'Y': 0.777752697467804},
#                            {'X': 0.16440127789974213, 'Y': 0.777752697467804}]},
#   'Id': 'ce87d650-e473-4dc9-9600-eab8c8788fe2',
#   'Relationships': [{'Ids': ['373620c1-d2d4-4797-9244-961ad30f4da5'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 4,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 2,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.020678702741861343,
#                                'Left': 0.23878267407417297,
#                                'Top': 0.7570739984512329,
#                                'Width': 0.23244184255599976},
#                'Polygon': [{'X': 0.23878267407417297, 'Y': 0.7570739984512329},
#                            {'X': 0.47122451663017273, 'Y': 0.7570739984512329},
#                            {'X': 0.47122451663017273, 'Y': 0.777752697467804},
#                            {'X': 0.23878267407417297, 'Y': 0.777752697467804}]},
#   'Id': 'a8db2186-1a26-4291-8876-a42974e4a00c',
#   'Relationships': [{'Ids': ['698f8e69-a19e-44a4-ba0a-55a1961268d0',
#                              '6610f66d-1e44-409d-9583-12c24bfe570b',
#                              '137cce40-1ccf-4d78-8f59-6566984ba15a',
#                              '91e259dc-8b71-4dac-8100-46d9f9d00018',
#                              'b030a66d-dbd8-4dcd-aefa-a4918e38264a'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 4,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 3,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.020678702741861343,
#                                'Left': 0.47122451663017273,
#                                'Top': 0.7570739984512329,
#                                'Width': 0.38740307092666626},
#                'Polygon': [{'X': 0.47122451663017273, 'Y': 0.7570739984512329},
#                            {'X': 0.8586275577545166, 'Y': 0.7570739984512329},
#                            {'X': 0.8586275577545166, 'Y': 0.777752697467804},
#                            {'X': 0.47122451663017273, 'Y': 0.777752697467804}]},
#   'Id': '0650af5a-c70c-4e2c-bb1f-9b51e0dc2245',
#   'RowIndex': 4,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 1,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.020678702741861343,
#                                'Left': 0.16440127789974213,
#                                'Top': 0.777752697467804,
#                                'Width': 0.07438138872385025},
#                'Polygon': [{'X': 0.16440127789974213, 'Y': 0.777752697467804},
#                            {'X': 0.23878267407417297, 'Y': 0.777752697467804},
#                            {'X': 0.23878267407417297, 'Y': 0.798431396484375},
#                            {'X': 0.16440127789974213, 'Y': 0.798431396484375}]},
#   'Id': '8fafa15e-37b5-4b6e-a10b-80396f19280b',
#   'Relationships': [{'Ids': ['9cbbbf8c-423f-495c-90d4-27cdbb3e6abe'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 5,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 2,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.020678702741861343,
#                                'Left': 0.23878267407417297,
#                                'Top': 0.777752697467804,
#                                'Width': 0.23244184255599976},
#                'Polygon': [{'X': 0.23878267407417297, 'Y': 0.777752697467804},
#                            {'X': 0.47122451663017273, 'Y': 0.777752697467804},
#                            {'X': 0.47122451663017273, 'Y': 0.798431396484375},
#                            {'X': 0.23878267407417297, 'Y': 0.798431396484375}]},
#   'Id': 'bf3016e7-a6e4-46dc-8f7d-e5b29bd6b54e',
#   'Relationships': [{'Ids': ['3bf101ec-c385-4c01-979a-b8f5853f683d',
#                              '43e4c0d7-a570-414c-b713-8bca53efbb3e'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 5,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 3,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.020678702741861343,
#                                'Left': 0.47122451663017273,
#                                'Top': 0.777752697467804,
#                                'Width': 0.38740307092666626},
#                'Polygon': [{'X': 0.47122451663017273, 'Y': 0.777752697467804},
#                            {'X': 0.8586275577545166, 'Y': 0.777752697467804},
#                            {'X': 0.8586275577545166, 'Y': 0.798431396484375},
#                            {'X': 0.47122451663017273, 'Y': 0.798431396484375}]},
#   'Id': '1b7b4867-2a11-476e-9c81-e55124c1c68b',
#   'RowIndex': 5,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 1,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.019953133538365364,
#                                'Left': 0.16440127789974213,
#                                'Top': 0.798431396484375,
#                                'Width': 0.07438138872385025},
#                'Polygon': [{'X': 0.16440127789974213, 'Y': 0.798431396484375},
#                            {'X': 0.23878267407417297, 'Y': 0.798431396484375},
#                            {'X': 0.23878267407417297, 'Y': 0.8183845281600952},
#                            {'X': 0.16440127789974213,
#                             'Y': 0.8183845281600952}]},
#   'Id': 'c2dbbcc9-6a7b-400a-9aa4-568da1a6aa0e',
#   'Relationships': [{'Ids': ['8674c5af-abb1-4d1b-a816-09b006f402b0'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 6,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 2,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.019953133538365364,
#                                'Left': 0.23878267407417297,
#                                'Top': 0.798431396484375,
#                                'Width': 0.23244184255599976},
#                'Polygon': [{'X': 0.23878267407417297, 'Y': 0.798431396484375},
#                            {'X': 0.47122451663017273, 'Y': 0.798431396484375},
#                            {'X': 0.47122451663017273, 'Y': 0.8183845281600952},
#                            {'X': 0.23878267407417297,
#                             'Y': 0.8183845281600952}]},
#   'Id': '0059e80e-9165-4923-b9fc-ea13ad0625ea',
#   'Relationships': [{'Ids': ['8f433461-50ca-4985-91dd-00c63b94dc94'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 6,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 3,
#   'ColumnSpan': 1,
#   'Confidence': 99.99847412109375,
#   'Geometry': {'BoundingBox': {'Height': 0.019953133538365364,
#                                'Left': 0.47122451663017273,
#                                'Top': 0.798431396484375,
#                                'Width': 0.38740307092666626},
#                'Polygon': [{'X': 0.47122451663017273, 'Y': 0.798431396484375},
#                            {'X': 0.8586275577545166, 'Y': 0.798431396484375},
#                            {'X': 0.8586275577545166, 'Y': 0.8183845281600952},
#                            {'X': 0.47122451663017273,
#                             'Y': 0.8183845281600952}]},
#   'Id': '6e0ccb61-2aaf-4521-b518-a68c12d6c145',
#   'RowIndex': 6,
#   'RowSpan': 1}]
# CSV OUTPUT FILE:  output.csv

# %%
print(type(table_csv))
# Out:
# <class 'str'>

# %%
with open(output_file, "w") as fout:
    fout.write("main hoon gian")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-16-bcc3b1ee2c68> in <module>
# ----> 1 with open(output_file, "w") as fout:
#       2     fout.write("main hoon gian")
#
# PermissionError: [Errno 13] Permission denied: 'output.csv'

# %%
import csv
with open('output_file.csv', mode='w') as csv_file:
    
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

# %%
type(table_csv)
# Out:
# str
